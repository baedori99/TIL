# %% [markdown]
# # 인턴 교육 2주차 과제: 네이버 OPEN API를 통한 웹 크롤링
# - 과제 기한: 6월 14일까지

# %% [markdown]
# **세부과제**
# 1. 네이버 OPEN API 이용
#     - 검색어에 대한 20개의 상품을 찾는다.
#     - 중고, 렌탈은 제외한다.
#
# 2. Pandas를 이용한 데이터프레임 저장
#     - 출력된 각 key들의 의미에 대해 이해한다.
#     - (column: 상품id, 상품명, 제조사, 최저가, 이미지링크, 구매링크)을 가진 데이터프레임을 만든다.(변수명은 자유)
#     - csv로 저장한다.
#
# 3. Python 코드로 함수 작성
#     - 키워드(검색어)만 입력하면 바로 저장될 수 있도록 함수를 만든다.
#         - 키워드를 입력하면 API를 이용해 데이터를 받고 이를 데이터프레임에 저장을 한뒤 자동으로 저장될 수 있게 한다.

# %% [markdown]
# **목표**
#
# 업무 자동화 시스템을 만들면서 OPEN API에 대한 이해와 데이터 저장에 대한 스킬을 높인다.

# %% [markdown]
# **팁**
#
# 1. [네이버 OPEN API에 대한 가이드](https://developers.naver.com/docs/common/openapiguide/)
#
# 2. [Pandas API reference](https://pandas.pydata.org/docs/reference/index.html)
#
# 3. [Python Documentation](https://docs.python.org/ko/3/library/urllib.html)
#
# 4. [Python json module Documentation](https://docs.python.org/3/library/json.html#)

# %% [markdown]
# 1. API데이터를 함수를 통해 받는 코드 작성

# %%
import os
import urllib.parse
import urllib.request

from dotenv import load_dotenv

load_dotenv()

def searh_naver_shopping(keyword):
    
    client_id = os.getenv("NAVER_CLIENT_ID")
    client_key = os.getenv("NAVER_CLIENT_KEY")
    
    encrypt_text = urllib.parse.quote(keyword)
    
    url = "https://openapi.naver.com/v1/search/shop?query="+ encrypt_text +"&display=20&exclude=used:rental"

    req_url = urllib.request.Request(url)
    
    req_url.add_header("X-Naver-Client-Id", client_id)
    req_url.add_header("X-Naver-Client-Secret", client_key)
    
    response = urllib.request.urlopen(req_url)
    resp_code = response.getcode()

    if resp_code == 200:
        shop_output = response.read().decode("utf-8")
    else:
        shop_output = "Error" + resp_code
    
    return shop_output

# %%
keyword_input = searh_naver_shopping("반팔티")
print(keyword_input)
print(type(keyword_input))
# Out:
# {
# 	"lastBuildDate":"Fri, 07 Jun 2024 11:06:45 +0900",
# 	"total":18903119,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"남여공용 스투시 베이직 로고 <b>반팔티셔츠<\/b> BLACKWHITE -",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40655140276",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4065514\/40655140276.20240526074654.jpg",
# 			"lprice":"39020",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"40655140276",
# 			"productType":"1",
# 			"brand":"스투시",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지오다노 코튼 피케 폴로 <b>반팔 티셔츠<\/b> 013502",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=46139137391",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4613913\/46139137391.20240531124510.jpg",
# 			"lprice":"11700",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46139137391",
# 			"productType":"1",
# 			"brand":"지오다노",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"타미힐피거 커플 여름 PK <b>반팔<\/b> 카라티",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=47181793552",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4718179\/47181793552.20240419150824.jpg",
# 			"lprice":"29580",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"47181793552",
# 			"productType":"1",
# 			"brand":"타미힐피거",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"무지티 남자 <b>반팔티<\/b> 17수 32수 오버핏 빅사이즈",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=85701462677",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8570146\/85701462677.3.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"FLEX SHOP 플렉스샵",
# 			"productId":"85701462677",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 남성 슬림핏 카라 <b>반팔 티셔츠<\/b> PH4012",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=38988916962",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3898891\/38988916962.20240314122523.jpg",
# 			"lprice":"43600",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"38988916962",
# 			"productType":"1",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"남자 <b>반팔티<\/b> 무지 티셔츠 17수 32수",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=84618944775",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8461894\/84618944775.6.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"후리찌",
# 			"productId":"84618944775",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>반팔티<\/b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=86472451126",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8647245\/86472451126.1.jpg",
# 			"lprice":"4890",
# 			"hprice":"",
# 			"mallName":"로파제",
# 			"productId":"86472451126",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"탑텐 남성 쿨에어 코튼 <b>반팔 티<\/b> 오버핏 MSD2TS1001",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=45171972049",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4517197\/45171972049.20240318123751.jpg",
# 			"lprice":"13290",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"45171972049",
# 			"productType":"1",
# 			"brand":"탑텐",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"칼하트 K87 워크웨어 포켓 <b>반팔티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=44910813703",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4491081\/44910813703.20240524082825.jpg",
# 			"lprice":"21900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"44910813703",
# 			"productType":"1",
# 			"brand":"칼하트",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"탑텐 남성 쿨에어 심리스 브이넥 <b>반팔 티<\/b> MSD2US1211",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=45229965521",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4522996\/45229965521.20240502163200.jpg",
# 			"lprice":"8040",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"45229965521",
# 			"productType":"1",
# 			"brand":"탑텐",
# 			"maker":"신성통상",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지프 남성 소로나 <b>반팔<\/b> 라운드 <b>티셔츠<\/b> 4종",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=46900319035",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4690031\/46900319035.20240406115242.jpg",
# 			"lprice":"32900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46900319035",
# 			"productType":"1",
# 			"brand":"지프",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"(매장판) 아디다스 <b>반팔티<\/b> 기능성 쿨 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=84146415087",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8414641\/84146415087.6.jpg",
# 			"lprice":"11000",
# 			"hprice":"",
# 			"mallName":"스니커오프",
# 			"productId":"84146415087",
# 			"productType":"2",
# 			"brand":"아디다스",
# 			"maker":"아디다스",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"베이직하우스 베이직 면 30수 3팩 무지 <b>반팔티셔츠<\/b> 교복티 솔리드티",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=45710762701",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4571076\/45710762701.20240530032833.jpg",
# 			"lprice":"17890",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"45710762701",
# 			"productType":"1",
# 			"brand":"베이직하우스",
# 			"maker":"티비에이치글로벌",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 <b>반팔티<\/b> 크루넥 베이직 라운드 여름 티셔츠",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=87099744126",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8709974\/87099744126.jpg",
# 			"lprice":"34900",
# 			"hprice":"",
# 			"mallName":"퀵스마트 스토어",
# 			"productId":"87099744126",
# 			"productType":"2",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"MINIMALPROJECT 로버스트 헤비 오버핏 <b>반팔티셔츠<\/b> MINT MST127",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=40169941411",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4016994\/40169941411.20230522171956.jpg",
# 			"lprice":"19404",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"40169941411",
# 			"productType":"1",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"(매장판) 나이키 <b>반팔티<\/b> 기능성 드라이핏 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=84658035941",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8465803\/84658035941.16.jpg",
# 			"lprice":"15900",
# 			"hprice":"",
# 			"mallName":"웨이업",
# 			"productId":"84658035941",
# 			"productType":"2",
# 			"brand":"나이키",
# 			"maker":"나이키",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"메종키츠네 <b>반팔티<\/b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=82425930806",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8242593\/82425930806.11.jpg",
# 			"lprice":"91000",
# 			"hprice":"",
# 			"mallName":"브랜드리퍼블릭",
# 			"productId":"82425930806",
# 			"productType":"2",
# 			"brand":"메종키츠네",
# 			"maker":"메종키츠네",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"타미힐피거 타미힐피거 남여공용 타미TH로고 라운드넥 <b>반팔티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=46904393275",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4690439\/46904393275.20240406180756.jpg",
# 			"lprice":"23840",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46904393275",
# 			"productType":"1",
# 			"brand":"타미힐피거",
# 			"maker":"타미힐피거",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지오다노카라티 피케 폴로티 <b>반팔티셔츠<\/b> 014502",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=87719064917",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8771906\/87719064917.jpg",
# 			"lprice":"16920",
# 			"hprice":"",
# 			"mallName":"지오다노",
# 			"productId":"87719064917",
# 			"productType":"2",
# 			"brand":"지오다노",
# 			"maker":"지오다노",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/gate.nhn?id=31709924618",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3170992\/31709924618.20220410213528.jpg",
# 			"lprice":"27900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"31709924618",
# 			"productType":"1",
# 			"brand":"커버낫",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		}
# 	]
# }
# <class 'str'>

# %%
import json
import pandas as pd

json_input = json.loads(keyword_input)
# print(json_input)
print(json.dumps(json_input))
# shop_review=pd.read_json(path_or_buf="", orient=json_input)
with open("naver_shopping.json", 'w', encoding="utf-8") as json_file:
    json.dump(json_input, json_file, ensure_ascii=False, sort_keys=True, indent="\t")
# Out:
# {"lastBuildDate": "Fri, 07 Jun 2024 11:06:45 +0900", "total": 18903119, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/gate.nhn?id=40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "39020", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/gate.nhn?id=46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ud0c0\ubbf8\ud790\ud53c\uac70 \ucee4\ud50c \uc5ec\ub984 PK <b>\ubc18\ud314</b> \uce74\ub77c\ud2f0", "link": "https://search.shopping.naver.com/gate.nhn?id=47181793552", "image": "https://shopping-phinf.pstatic.net/main_4718179/47181793552.20240419150824.jpg", "lprice": "29580", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "47181793552", "productType": "1", "brand": "\ud0c0\ubbf8\ud790\ud53c\uac70", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://search.shopping.naver.com/gate.nhn?id=85701462677", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/gate.nhn?id=38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://search.shopping.naver.com/gate.nhn?id=84618944775", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice": "5900", "hprice": "", "mallName": "\ud6c4\ub9ac\ucc0c", "productId": "84618944775", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://search.shopping.naver.com/gate.nhn?id=86472451126", "image": "https://shopping-phinf.pstatic.net/main_8647245/8 ...

# %%
print(json.dumps(json_input))
# Out:
# {"lastBuildDate": "Fri, 07 Jun 2024 11:06:45 +0900", "total": 18903119, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/gate.nhn?id=40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "39020", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/gate.nhn?id=46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ud0c0\ubbf8\ud790\ud53c\uac70 \ucee4\ud50c \uc5ec\ub984 PK <b>\ubc18\ud314</b> \uce74\ub77c\ud2f0", "link": "https://search.shopping.naver.com/gate.nhn?id=47181793552", "image": "https://shopping-phinf.pstatic.net/main_4718179/47181793552.20240419150824.jpg", "lprice": "29580", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "47181793552", "productType": "1", "brand": "\ud0c0\ubbf8\ud790\ud53c\uac70", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://search.shopping.naver.com/gate.nhn?id=85701462677", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/gate.nhn?id=38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://search.shopping.naver.com/gate.nhn?id=84618944775", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice": "5900", "hprice": "", "mallName": "\ud6c4\ub9ac\ucc0c", "productId": "84618944775", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://search.shopping.naver.com/gate.nhn?id=86472451126", "image": "https://shopping-phinf.pstatic.net/main_8647245/8 ...

# %% [markdown]
# [Pandas.read_json에 대한 설명](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
import pandas as pd

# %%
# naver_news_shopping.json의 경로를 설정해준다.
df = pd.read_json('naver_shopping.json')
df
# Out:
#     display                                              items  \
# 0        20  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 1        20  {'brand': '지오다노', 'category1': '패션의류', 'catego...
# 2        20  {'brand': '타미힐피거', 'category1': '패션의류', 'categ...
# 3        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 4        20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 5        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 6        20  {'brand': '', 'category1': '패션의류', 'category2'...
# 7        20  {'brand': '탑텐', 'category1': '패션의류', 'category...
# 8        20  {'brand': '칼하트', 'category1': '패션의류', 'categor...
# 9        20  {'brand': '탑텐', 'category1': '패션의류', 'category...
# 10       20  {'brand': '지프', 'category1': '패션의류', 'category...
# 11       20  {'brand': '아디다스', 'category1': '패션의류', 'catego...
# 12       20  {'brand': '베이직하우스', 'category1': '패션의류', 'cate...
# 13       20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 14       20  {'brand': '', 'category1': '패션의류', 'category2'...
# 15       20  {'brand': '나이키', 'category1': '패션의류', 'categor...
# 16       20  {'brand': '메종키츠네', 'category1': '패션의류', 'categ...
# 17       20  {'brand': '타미힐피거', 'category1': '패션의류', 'categ...
# 18       20  {'brand': '지오다노', 'category1': '패션의류', 'catego...
# 19       20  {'brand': '커버낫', 'category1': '패션의류', 'categor...
#
#                       lastBuildDate  start     total
# 0   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 1   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 2   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 3   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 4   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 5   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 6   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 7   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 8   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 9   Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 10  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 11  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 12  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 13  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 14  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 15  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 16  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 17  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 18  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119
# 19  Fri, 07 Jun 2024 11:06:45 +0900      1  18903119

# %%
# 문제 발생! item 항목에 brand category등 분류가 안되게 들어갔음.

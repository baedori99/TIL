# %% [markdown]
# # 인턴 교육 2주차 과제: 네이버 OPEN API를 통한 웹 크롤링
# - 과제 기한: 6월 14일까지

# %% [markdown]
# **세부과제**
# 1. 네이버 OPEN API 이용
#     - 검색어에 대한 20개의 상품을 찾는다.
#     - 중고, 렌탈은 제외한다.
#
# 2. Pandas를 이용한 데이터프레임 저장
#     - 출력된 각 key들의 의미에 대해 이해한다.
#     - (column: 상품id, 상품명, 제조사, 최저가, 이미지링크, 구매링크)을 가진 데이터프레임을 만든다.(변수명은 자유)
#     - csv로 저장한다.
#
# 3. Python 코드로 함수 작성
#     - 키워드(검색어)만 입력하면 바로 저장될 수 있도록 함수를 만든다.
#         - 키워드를 입력하면 API를 이용해 데이터를 받고 이를 데이터프레임에 저장을 한뒤 자동으로 저장될 수 있게 한다.

# %% [markdown]
# **목표**
#
# 업무 자동화 시스템을 만들면서 OPEN API에 대한 이해와 데이터 저장에 대한 스킬을 높인다.

# %% [markdown]
# **팁**
#
# 1. [네이버 OPEN API에 대한 가이드](https://developers.naver.com/docs/common/openapiguide/)
#
# 2. [Pandas API reference](https://pandas.pydata.org/docs/reference/index.html)
#
# 3. [Python Documentation](https://docs.python.org/ko/3/library/urllib.html)
#
# 4. [Python json module Documentation](https://docs.python.org/3/library/json.html#)

# %% [markdown]
# 1. API데이터를 함수를 통해 받는 코드 작성

# %%
import os
import urllib.parse
import urllib.request

from dotenv import load_dotenv

load_dotenv()

def searh_naver_shopping(keyword):
    
    client_id = os.getenv("NAVER_CLIENT_ID")
    client_key = os.getenv("NAVER_CLIENT_KEY")
    
    encrypt_text = urllib.parse.quote(keyword)
    
    url = "https://openapi.naver.com/v1/search/shop?query="+ encrypt_text +"&display=20&exclude=used:rental"

    req_url = urllib.request.Request(url)
    
    req_url.add_header("X-Naver-Client-Id", client_id)
    req_url.add_header("X-Naver-Client-Secret", client_key)
    
    response = urllib.request.urlopen(req_url)
    resp_code = response.getcode()

    if resp_code == 200:
        shop_output = response.read().decode("utf-8")
    else:
        shop_output = "Error" + resp_code
    
    return shop_output

# %%
keyword_input = searh_naver_shopping("반팔티")
print(keyword_input)
print(type(keyword_input))
# Out:
# {
# 	"lastBuildDate":"Sun, 09 Jun 2024 20:33:03 +0900",
# 	"total":18972729,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"남여공용 스투시 베이직 로고 <b>반팔티셔츠<\/b> BLACKWHITE -",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/40655140276",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4065514\/40655140276.20240526074654.jpg",
# 			"lprice":"38770",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"40655140276",
# 			"productType":"1",
# 			"brand":"스투시",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"무지티 남자 <b>반팔티<\/b> 17수 32수 오버핏 빅사이즈",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8156962354",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8570146\/85701462677.3.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"FLEX SHOP 플렉스샵",
# 			"productId":"85701462677",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지오다노 코튼 피케 폴로 <b>반팔 티셔츠<\/b> 013502",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/46139137391",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4613913\/46139137391.20240531124510.jpg",
# 			"lprice":"11700",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46139137391",
# 			"productType":"1",
# 			"brand":"지오다노",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>반팔티<\/b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8927950803",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8647245\/86472451126.1.jpg",
# 			"lprice":"4890",
# 			"hprice":"",
# 			"mallName":"로파제",
# 			"productId":"86472451126",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"남자 <b>반팔티<\/b> 무지 티셔츠 17수 32수",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/7074444453",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8461894\/84618944775.6.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"후리찌",
# 			"productId":"84618944775",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 남성 슬림핏 카라 <b>반팔 티셔츠<\/b> PH4012",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/38988916962",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3898891\/38988916962.20240314122523.jpg",
# 			"lprice":"43600",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"38988916962",
# 			"productType":"1",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 <b>반팔티<\/b> 크루넥 베이직 라운드 여름 티셔츠",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/9555241856",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8709974\/87099744126.jpg",
# 			"lprice":"34900",
# 			"hprice":"",
# 			"mallName":"퀵스마트 스토어",
# 			"productId":"87099744126",
# 			"productType":"2",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"기능성 <b>반팔<\/b> 쿨<b>티셔츠<\/b> 남자 무지 쿨론 헬스 냉감 쿨링 운동 <b>티셔츠<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/6280651078",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8382515\/83825153567.7.jpg",
# 			"lprice":"5500",
# 			"hprice":"",
# 			"mallName":"FLEX SHOP 플렉스샵",
# 			"productId":"83825153567",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"메종키츠네 <b>반팔티<\/b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/4881407335",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8242593\/82425930806.11.jpg",
# 			"lprice":"91000",
# 			"hprice":"",
# 			"mallName":"브랜드리퍼블릭",
# 			"productId":"82425930806",
# 			"productType":"2",
# 			"brand":"메종키츠네",
# 			"maker":"메종키츠네",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"타미힐피거 커플 여름 PK <b>반팔<\/b> 카라티",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/47181793552",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4718179\/47181793552.20240419150824.jpg",
# 			"lprice":"29580",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"47181793552",
# 			"productType":"1",
# 			"brand":"타미힐피거",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지프 남성 소로나 <b>반팔<\/b> 라운드 <b>티셔츠<\/b> 4종",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/46900319035",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4690031\/46900319035.20240406115242.jpg",
# 			"lprice":"32900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46900319035",
# 			"productType":"1",
# 			"brand":"지프",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/31709924618",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3170992\/31709924618.20220410213528.jpg",
# 			"lprice":"30830",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"31709924618",
# 			"productType":"1",
# 			"brand":"커버낫",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"칼하트 K87 워크웨어 포켓 <b>반팔티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/44910813703",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4491081\/44910813703.20240524082825.jpg",
# 			"lprice":"21900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"44910813703",
# 			"productType":"1",
# 			"brand":"칼하트",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"탑텐 남성 쿨에어 코튼 <b>반팔 티<\/b> 오버핏 MSD2TS1001",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/45171972049",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4517197\/45171972049.20240318123751.jpg",
# 			"lprice":"14870",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"45171972049",
# 			"productType":"1",
# 			"brand":"탑텐",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"(매장판) 아디다스 <b>반팔티<\/b> 기능성 쿨 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/6601914765",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8414641\/84146415087.6.jpg",
# 			"lprice":"11000",
# 			"hprice":"",
# 			"mallName":"스니커오프",
# 			"productId":"84146415087",
# 			"productType":"2",
# 			"brand":"아디다스",
# 			"maker":"아디다스",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 <b>반팔티<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/4502556456",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8204707\/82047079376.10.jpg",
# 			"lprice":"19800",
# 			"hprice":"",
# 			"mallName":"에프오유",
# 			"productId":"82047079376",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"쿨티셔츠 냉감 기능성 라운드 <b>반팔티<\/b> 긴팔 남자 여름 남성 봄 스판 냉장고 반목 빅사이즈",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/7676985353",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8522148\/85221485675.5.jpg",
# 			"lprice":"4700",
# 			"hprice":"",
# 			"mallName":"산토초이",
# 			"productId":"85221485675",
# 			"productType":"2",
# 			"brand":"산토초이",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"나이키 <b>반팔티셔츠<\/b> 남여공용 클럽로고 스우시 에어조던 커플티셔츠",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/5577068485",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8312156\/83121564557.17.jpg",
# 			"lprice":"26990",
# 			"hprice":"",
# 			"mallName":"미니레어마켓",
# 			"productId":"83121564557",
# 			"productType":"2",
# 			"brand":"나이키",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"[국내 도착보장] 스투시 로고 <b>반팔 티셔츠<\/b> 낱개 3팩 세트 레이어드용",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/10120852781",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8766535\/87665355657.jpg",
# 			"lprice":"35000",
# 			"hprice":"",
# 			"mallName":"메종파르코",
# 			"productId":"87665355657",
# 			"productType":"2",
# 			"brand":"스투시",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"폴로<b>반팔티<\/b> 폴로 랄프로렌 라운드 여름 티셔츠",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8179762663",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8572426\/85724262986.2.jpg",
# 			"lprice":"25600",
# 			"hprice":"",
# 			"mallName":"퀵스마트 스토어",
# 			"productId":"85724262986",
# 			"productType":"2",
# 			"brand":"폴로랄프로렌",
# 			"maker":"폴로랄프로렌",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		}
# 	]
# }
# <class 'str'>

# %%
import json
import pandas as pd

json_input = json.loads(keyword_input)
# print(json_input)
print(json.dumps(json_input))
# shop_review=pd.read_json(path_or_buf="", orient=json_input)
with open("naver_shopping.json", 'w', encoding="utf-8") as json_file:
    json.dump(json_input, json_file, ensure_ascii=False, sort_keys=True, indent="\t")
# Out:
# {"lastBuildDate": "Sun, 09 Jun 2024 20:33:03 +0900", "total": 18972729, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/catalog/40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "38770", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://smartstore.naver.com/main/products/8156962354", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/catalog/46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://smartstore.naver.com/main/products/8927950803", "image": "https://shopping-phinf.pstatic.net/main_8647245/86472451126.1.jpg", "lprice": "4890", "hprice": "", "mallName": "\ub85c\ud30c\uc81c", "productId": "86472451126", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://smartstore.naver.com/main/products/7074444453", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice": "5900", "hprice": "", "mallName": "\ud6c4\ub9ac\ucc0c", "productId": "84618944775", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/catalog/38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c <b>\ubc18\ud314\ud2f0</b> \ud06c\ub8e8\ub125 \ubca0\uc774\uc9c1 \ub77c\uc6b4\ub4dc \uc5ec\ub984 \ud2f0\uc154\uce20", "link": "https://smartstore.naver.com/main/products/9555241856", "image": "https://shopping-phinf.pstatic.net/main_8709974/87099744126.jpg", "lprice": "349 ...

# %%
print(json.dumps(json_input))
# Out:
# {"lastBuildDate": "Sun, 09 Jun 2024 20:33:03 +0900", "total": 18972729, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/catalog/40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "38770", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://smartstore.naver.com/main/products/8156962354", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/catalog/46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://smartstore.naver.com/main/products/8927950803", "image": "https://shopping-phinf.pstatic.net/main_8647245/86472451126.1.jpg", "lprice": "4890", "hprice": "", "mallName": "\ub85c\ud30c\uc81c", "productId": "86472451126", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://smartstore.naver.com/main/products/7074444453", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice": "5900", "hprice": "", "mallName": "\ud6c4\ub9ac\ucc0c", "productId": "84618944775", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/catalog/38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c <b>\ubc18\ud314\ud2f0</b> \ud06c\ub8e8\ub125 \ubca0\uc774\uc9c1 \ub77c\uc6b4\ub4dc \uc5ec\ub984 \ud2f0\uc154\uce20", "link": "https://smartstore.naver.com/main/products/9555241856", "image": "https://shopping-phinf.pstatic.net/main_8709974/87099744126.jpg", "lprice": "349 ...

# %% [markdown]
# [Pandas.read_json에 대한 설명](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
import pandas as pd

# %%
# naver_news_shopping.json의 경로를 설정해준다.
df = pd.read_json('naver_shopping.json')
df
# Out:
#     display                                              items  \
# 0        20  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 1        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 2        20  {'brand': '지오다노', 'category1': '패션의류', 'catego...
# 3        20  {'brand': '', 'category1': '패션의류', 'category2'...
# 4        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 5        20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 6        20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 7        20  {'brand': '', 'category1': '패션의류', 'category2'...
# 8        20  {'brand': '메종키츠네', 'category1': '패션의류', 'categ...
# 9        20  {'brand': '타미힐피거', 'category1': '패션의류', 'categ...
# 10       20  {'brand': '지프', 'category1': '패션의류', 'category...
# 11       20  {'brand': '커버낫', 'category1': '패션의류', 'categor...
# 12       20  {'brand': '칼하트', 'category1': '패션의류', 'categor...
# 13       20  {'brand': '탑텐', 'category1': '패션의류', 'category...
# 14       20  {'brand': '아디다스', 'category1': '패션의류', 'catego...
# 15       20  {'brand': '', 'category1': '패션의류', 'category2'...
# 16       20  {'brand': '산토초이', 'category1': '패션의류', 'catego...
# 17       20  {'brand': '나이키', 'category1': '패션의류', 'categor...
# 18       20  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 19       20  {'brand': '폴로랄프로렌', 'category1': '패션의류', 'cate...
#
#                       lastBuildDate  start     total
# 0   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 1   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 2   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 3   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 4   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 5   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 6   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 7   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 8   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 9   Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 10  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 11  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 12  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 13  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 14  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 15  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 16  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 17  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 18  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729
# 19  Sun, 09 Jun 2024 20:33:03 +0900      1  18972729

# %% [markdown]
# - 문제 발생! item 항목에 brand category등 분류가 안되게 들어갔음.
# - Parsing을 해줘야하는데 어떻게 해야하는지 감이 안잡힘...\
# - `rename`을 써줘야하나 일단 columns들을 영어변수로 바꿔서 편리하게 해보자

# %% [markdown]
# - column: 상품id, 상품명, 제조사, 최저가, 이미지링크, 구매링크
# - df.columns = ["product_id","product_name","brand_name","low_price","img_link","buy_link"]
# - columns 갯수를 넘어가므로 일단 만들어두고 JSON file의 key value 부분을 columns로 쓰는 방법에 대해서 고민을 해보자.
# - 1. rename에 대한 방법
# - 2. set_axis에 대한 방법  [set_axis](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html)
# - 3. pivot_table에 대한 방법 - item열에 있는 것을 columns로 바꾼다는 아이디어 [Pivot_table](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot_table.html#pandas.DataFrame.pivot_table)

# %%
# shopping_review = df["items"].pivot_table(columns="productId","title","brand","lprice","image","link")

# %% [markdown]
# - concat에 대해서 찾아보다가 to_frame()함수에 대해서 찾음 [concat/to_frame()](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)

# %%
# to_frame()
item_reviews = df["items"].to_frame()
# Out:
#                                                 items
# 0   {'brand': '스투시', 'category1': '패션의류', 'categor...
# 1   {'brand': '지오다노', 'category1': '패션의류', 'catego...
# 2   {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 3   {'brand': '타미힐피거', 'category1': '패션의류', 'categ...
# 4   {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 5   {'brand': '', 'category1': '패션의류', 'category2'...
# 6   {'brand': '아디다스', 'category1': '패션의류', 'catego...
# 7   {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 8   {'brand': '산토초이', 'category1': '패션의류', 'catego...
# 9   {'brand': '메종키츠네', 'category1': '패션의류', 'categ...
# 10  {'brand': '폴로랄프로렌', 'category1': '패션의류', 'cate...
# 11  {'brand': '', 'category1': '패션의류', 'category2'...
# 12  {'brand': '', 'category1': '패션의류', 'category2'...
# 13  {'brand': '폴로', 'category1': '패션의류', 'category...
# 14  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 15  {'brand': '탑텐', 'category1': '패션의류', 'category...
# 16  {'brand': '칼하트', 'category1': '패션의류', 'categor...
# 17  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 18  {'brand': '', 'category1': '패션의류', 'category2'...
# 19  {'brand': '탑텐', 'category1': '패션의류', 'category...

# %% [markdown]
# [json_normalize 문서](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html#pandas-json-normalize)

# %%
# 문제 해결
# json_normalize() 함수를 써야함.
from pandas import json_normalize

shopping_info = json_normalize(json_input["items"])
shopping_info
# Out:
#                                                 title  \
# 0           남여공용 스투시 베이직 로고 <b>반팔티셔츠</b> BLACKWHITE -
# 1                  무지티 남자 <b>반팔티</b> 17수 32수 오버핏 빅사이즈
# 2                  지오다노 코튼 피케 폴로 <b>반팔 티셔츠</b> 013502
# 3           <b>반팔티</b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티
# 4                        남자 <b>반팔티</b> 무지 티셔츠 17수 32수
# 5                 라코스테 남성 슬림핏 카라 <b>반팔 티셔츠</b> PH4012
# 6                  라코스테 <b>반팔티</b> 크루넥 베이직 라운드 여름 티셔츠
# 7   기능성 <b>반팔</b> 쿨<b>티셔츠</b> 남자 무지 쿨론 헬스 냉감 쿨링 운동...
# 8              메종키츠네 <b>반팔티</b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅
# 9                        타미힐피거 커플 여름 PK <b>반팔</b> 카라티
# 10              지프 남성 소로나 <b>반팔</b> 라운드 <b>티셔츠</b> 4종
# 11                 커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠</b>
# 12                       칼하트 K87 워크웨어 포켓 <b>반팔티셔츠</b>
# 13            탑텐 남성 쿨에어 코튼 <b>반팔 티</b> 오버핏 MSD2TS1001
# 14          (매장판) 아디다스 <b>반팔티</b> 기능성 쿨 <b>반팔 티셔츠</b>
# 15                남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 <b>반팔티</b>
# 16  쿨티셔츠 냉감 기능성 라운드 <b>반팔티</b> 긴팔 남자 여름 남성 봄 스판 냉장...
# 17          나이키 <b>반팔티셔츠</b> 남여공용 클럽로고 스우시 에어조던 커플티셔츠
# 18      [국내 도착보장] 스투시 로고 <b>반팔 티셔츠</b> 낱개 3팩 세트 레이어드용
# 19                    폴로<b>반팔티</b> 폴로 랄프로렌 라운드 여름 티셔츠
#
#                                                  link  \
# 0   https://search.shopping.naver.com/catalog/4065...
# 1   https://smartstore.naver.com/main/products/815...
# 2   https://search.shopping.naver.com/catalog/4613...
# 3   https://smartstore.naver.com/main/products/892...
# 4   https://smartstore.naver.com/main/products/707...
# 5   https://search.shopping.naver.com/catalog/3898...
# 6   https://smartstore.naver.com/main/products/955...
# 7   https://smartstore.naver.com/main/products/628...
# 8   https://smartstore.naver.com/main/products/488...
# 9   https://search.shopping.naver.com/catalog/4718...
# 10  https://search.shopping.naver.com/catalog/4690...
# 11  https://search.shopping.naver.com/catalog/3170...
# 12  https://search.shopping.naver.com/catalog/4491...
# 13  https://search.shopping.naver.com/catalog/4517...
# 14  https://smartstore.naver.com/main/products/660...
# 15  https://smartstore.naver.com/main/products/450...
# 16  https://smartstore.naver.com/main/products/767...
# 17  https://smartstore.naver.com/main/products/557...
# 18  https://smartstore.naver.com/main/products/101...
# 19  https://smartstore.naver.com/main/products/817...
#
#                                                 image lprice hprice  \
# 0   https://shopping-phinf.pstatic.net/main_406551...  38770
# 1   https://shopping-phinf.pstatic.net/main_857014...   5900
# 2   https://shopping-phinf.pstatic.net/main_461391...  11700
# 3   https://shopping-phinf.pstatic.net/main_864724...   4890
# 4   https://shopping-phinf.pstatic.net/main_846189...   5900
# 5   https://shopping-phinf.pstatic.net/main_389889...  43600
# 6   https://shopping-phinf.pstatic.net/main_870997...  34900
# 7   https://shopping-phinf.pstatic.net/main_838251...   5500
# 8   https://shopping-phinf.pstatic.net/main_824259...  91000
# 9   https://shopping-phinf.pstatic.net/main_471817...  29580
# 10  https://shopping-phinf.pstatic.net/main_469003...  32900
# 11  https://shopping-phinf.pstatic.net/main_317099...  30830
# 12  https://shopping-phinf.pstatic.net/main_449108...  21900
# 13  https://shopping-phinf.pstatic.net/main_451719...  14870
# 14  https://shopping-phinf.pstatic.net/main_841464...  11000
# 15  https://shopping-phinf.pstatic.net/main_820470...  19800
# 16  https://shopping-phinf.pstatic.net/main_852214...   4700
# 17  https://shopping-phinf.pstatic.net/main_831215...  26990
# 18  https://shopping-phinf.pstatic.net/main_876653...  35000
# 19  https://shopping-phinf.pstatic.net/main_857242...  25600
#
#           mallName    productId productType   brand   maker category1  \
# 0              네이버  40655140276           1     스투시              패션의류
# 1   FLEX SHOP 플렉스샵  85701462677           2   프린트스타   프린트스타      패션의류
# 2              네이버  46139137391           1    지오다노              패션의류
# 3              로파제  86472451126           2                      패션의류
# 4              후리찌  84618944775           2   프린트스타   프린트스타      패션의류
# 5              네이버  38988916962           1    라코스테    라코스테      패션의류
# 6         퀵스마트 스토어  87099744126           2    라코스테    라코스테      패션의류
# 7   FLEX SHOP 플렉스샵  83825153567           2                      패션의류
# 8          브랜드리퍼블릭  82425930806           2   메종키츠네   메종키츠네      패션의류
# 9              네이버  47181793552           1   타미힐피거              패션의류
# 10             네이버  46900319035           1      지프              패션의류
# 11             네이버  31709924618           1     커버낫              패션의류
# 12             네이버  44910813703           1     칼하트              패션의류
# 13             네이버  45171972049           1      탑텐              패션의류
# 14           스니커오프  84146415087           2    아디다스    아디다스      패션의류
# 15            에프오유  82047079376           2                      패션의류
# 16            산토초이  85221485675           2    산토초이              패션의류
# 17          미니레어마켓  83121564557           2     나이키              패션의류
# 18           메종파르코  87665355657           2     스투시              패션의류
# 19        퀵스마트 스토어  85724262986           2  폴로랄프로렌  폴로랄프로렌      패션의류
#
#    category2 category3 category4
# 0       남성의류       티셔츠
# 1       남성의류       티셔츠
# 2       남성의류       티셔츠
# 3       남성의류       티셔츠
# 4       남성의류       티셔츠
# 5       남성의류       티셔츠
# 6       남성의류       티셔츠
# 7       남성의류       티셔츠
# 8       남성의류       티셔츠
# 9       남성의류       티셔츠
# 10      남성의류       티셔츠
# 11      남성의류       티셔츠
# 12      남성의류       티셔츠
# 13      남성의류       티셔츠
# 14      남성의류       티셔츠
# 15      남성의류       티셔츠
# 16      남성의류       티셔츠
# 17      남성의류       티셔츠
# 18      남성의류       티셔츠
# 19      남성의류       티셔츠

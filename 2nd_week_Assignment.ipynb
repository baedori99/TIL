# %% [markdown]
# # 인턴 교육 2주차 과제: 네이버 OPEN API를 통한 웹 크롤링
# - 과제 기한: 6월 14일까지
# - 제출자: 배정환 인턴

# %% [markdown]
# **세부과제**
# 1. 네이버 OPEN API 이용
#     - 검색어에 대한 20개의 상품을 찾는다.
#     - 중고, 렌탈은 제외한다.
#
# 2. Pandas를 이용한 데이터프레임 저장
#     - 출력된 각 key들의 의미에 대해 이해한다.
#     - (column: 상품id, 상품명, 제조사, 최저가, 이미지링크, 구매링크)을 가진 데이터프레임을 만든다.(변수명은 자유)
#     - csv로 저장한다.
#
# 3. Python 코드로 함수 작성
#     - 키워드(검색어)만 입력하면 바로 저장될 수 있도록 함수를 만든다.
#         - 키워드를 입력하면 API를 이용해 데이터를 받고 이를 데이터프레임에 저장을 한뒤 자동으로 저장될 수 있게 한다.

# %% [markdown]
# **목표**
#
# 업무 자동화 시스템을 만들면서 OPEN API에 대한 이해와 데이터 저장에 대한 스킬을 높인다.

# %% [markdown]
# **팁**
#
# 1. [네이버 OPEN API에 대한 가이드](https://developers.naver.com/docs/common/openapiguide/)
#
# 2. [Pandas API reference](https://pandas.pydata.org/docs/reference/index.html)
#
# 3. [Python Documentation](https://docs.python.org/ko/3/library/urllib.html)
#
# 4. [Python json module Documentation](https://docs.python.org/3/library/json.html#)

# %% [markdown]
# 1. API데이터를 함수를 통해 받는 코드 작성

# %%
import os
import urllib.parse
import urllib.request

from dotenv import load_dotenv

load_dotenv()

def searh_naver_shopping(keyword):
    
    client_id = os.getenv("NAVER_CLIENT_ID")
    client_key = os.getenv("NAVER_CLIENT_KEY")
    
    encrypt_text = urllib.parse.quote(keyword)
    
    url = "https://openapi.naver.com/v1/search/shop?query="+ encrypt_text +"&display=20&exclude=used:rental"

    req_url = urllib.request.Request(url)
    
    req_url.add_header("X-Naver-Client-Id", client_id)
    req_url.add_header("X-Naver-Client-Secret", client_key)
    
    response = urllib.request.urlopen(req_url)
    resp_code = response.getcode()

    if resp_code == 200:
        shop_output = response.read().decode("utf-8")
    else:
        shop_output = "Error" + resp_code
    
    return shop_output

# %%
keyword_input = searh_naver_shopping("반팔티")
print(keyword_input)
print(type(keyword_input))
# Out:
# {
# 	"lastBuildDate":"Mon, 10 Jun 2024 11:21:16 +0900",
# 	"total":19126815,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"남여공용 스투시 베이직 로고 <b>반팔티셔츠<\/b> BLACKWHITE -",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/40655140276",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4065514\/40655140276.20240526074654.jpg",
# 			"lprice":"34990",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"40655140276",
# 			"productType":"1",
# 			"brand":"스투시",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지오다노 코튼 피케 폴로 <b>반팔 티셔츠<\/b> 013502",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/46139137391",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4613913\/46139137391.20240531124510.jpg",
# 			"lprice":"11700",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46139137391",
# 			"productType":"1",
# 			"brand":"지오다노",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"무지티 남자 <b>반팔티<\/b> 17수 32수 오버핏 빅사이즈",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8156962354",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8570146\/85701462677.3.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"FLEX SHOP 플렉스샵",
# 			"productId":"85701462677",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"<b>반팔티<\/b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8927950803",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8647245\/86472451126.1.jpg",
# 			"lprice":"4890",
# 			"hprice":"",
# 			"mallName":"로파제",
# 			"productId":"86472451126",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 남성 슬림핏 카라 <b>반팔 티셔츠<\/b> PH4012",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/38988916962",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3898891\/38988916962.20240314122523.jpg",
# 			"lprice":"43600",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"38988916962",
# 			"productType":"1",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"기능성 <b>반팔<\/b> 쿨<b>티셔츠<\/b> 남자 무지 쿨론 헬스 냉감 쿨링 운동 <b>티셔츠<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/6280651078",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8382515\/83825153567.7.jpg",
# 			"lprice":"5500",
# 			"hprice":"",
# 			"mallName":"FLEX SHOP 플렉스샵",
# 			"productId":"83825153567",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"남자 <b>반팔티<\/b> 무지 티셔츠 17수 32수",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/7074444453",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8461894\/84618944775.6.jpg",
# 			"lprice":"5900",
# 			"hprice":"",
# 			"mallName":"후리찌",
# 			"productId":"84618944775",
# 			"productType":"2",
# 			"brand":"프린트스타",
# 			"maker":"프린트스타",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지프 남성 소로나 <b>반팔<\/b> 라운드 <b>티셔츠<\/b> 4종",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/46900319035",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4690031\/46900319035.20240406115242.jpg",
# 			"lprice":"32900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"46900319035",
# 			"productType":"1",
# 			"brand":"지프",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"라코스테 <b>반팔티<\/b> 크루넥 베이직 라운드 여름 티셔츠",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/9555241856",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8709974\/87099744126.jpg",
# 			"lprice":"34900",
# 			"hprice":"",
# 			"mallName":"퀵스마트 스토어",
# 			"productId":"87099744126",
# 			"productType":"2",
# 			"brand":"라코스테",
# 			"maker":"라코스테",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"타미힐피거 커플 여름 PK <b>반팔<\/b> 카라티",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/47181793552",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4718179\/47181793552.20240419150824.jpg",
# 			"lprice":"29580",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"47181793552",
# 			"productType":"1",
# 			"brand":"타미힐피거",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"칼하트 K87 워크웨어 포켓 <b>반팔티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/44910813703",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4491081\/44910813703.20240524082825.jpg",
# 			"lprice":"21900",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"44910813703",
# 			"productType":"1",
# 			"brand":"칼하트",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 <b>반팔티<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/4502556456",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8204707\/82047079376.10.jpg",
# 			"lprice":"19800",
# 			"hprice":"",
# 			"mallName":"에프오유",
# 			"productId":"82047079376",
# 			"productType":"2",
# 			"brand":"",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/31709924618",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3170992\/31709924618.20220410213528.jpg",
# 			"lprice":"32520",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"31709924618",
# 			"productType":"1",
# 			"brand":"커버낫",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"쿨티셔츠 냉감 기능성 라운드 <b>반팔티<\/b> 긴팔 남자 여름 남성 봄 스판 냉장고 반목 빅사이즈",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/7676985353",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8522148\/85221485675.5.jpg",
# 			"lprice":"4700",
# 			"hprice":"",
# 			"mallName":"산토초이",
# 			"productId":"85221485675",
# 			"productType":"2",
# 			"brand":"산토초이",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"스투시 스투시 멜티드 플라워 돌리 월드투어 트라이브 키튼 아워레가시 피그먼트 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/43875890304",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4387589\/43875890304.20231107145305.jpg",
# 			"lprice":"33800",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"43875890304",
# 			"productType":"1",
# 			"brand":"스투시",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"탑텐 남성 쿨에어 코튼 <b>반팔 티<\/b> 오버핏 MSD2TS1001",
# 			"link":"https:\/\/search.shopping.naver.com\/catalog\/45171972049",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_4517197\/45171972049.20240318123751.jpg",
# 			"lprice":"14930",
# 			"hprice":"",
# 			"mallName":"네이버",
# 			"productId":"45171972049",
# 			"productType":"1",
# 			"brand":"탑텐",
# 			"maker":"",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"(매장판) 아디다스 <b>반팔티<\/b> 기능성 쿨 <b>반팔 티셔츠<\/b>",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/6601914765",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8414641\/84146415087.6.jpg",
# 			"lprice":"11000",
# 			"hprice":"",
# 			"mallName":"스니커오프",
# 			"productId":"84146415087",
# 			"productType":"2",
# 			"brand":"아디다스",
# 			"maker":"아디다스",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"메종키츠네 <b>반팔티<\/b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/4881407335",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8242593\/82425930806.11.jpg",
# 			"lprice":"91000",
# 			"hprice":"",
# 			"mallName":"브랜드리퍼블릭",
# 			"productId":"82425930806",
# 			"productType":"2",
# 			"brand":"메종키츠네",
# 			"maker":"메종키츠네",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"폴로<b>반팔티<\/b> 폴로 랄프로렌 라운드 여름 티셔츠",
# 			"link":"https:\/\/smartstore.naver.com\/main\/products\/8179762663",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8572426\/85724262986.2.jpg",
# 			"lprice":"25600",
# 			"hprice":"",
# 			"mallName":"퀵스마트 스토어",
# 			"productId":"85724262986",
# 			"productType":"2",
# 			"brand":"폴로랄프로렌",
# 			"maker":"폴로랄프로렌",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		},
# 		{
# 			"title":"지오다노카라티 피케 폴로티 <b>반팔티셔츠<\/b> 014502",
# 			"link":"https:\/\/shopping.naver.com\/outlink\/itemdetail\/10174561575",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_8771906\/87719064917.jpg",
# 			"lprice":"16920",
# 			"hprice":"",
# 			"mallName":"지오다노",
# 			"productId":"87719064917",
# 			"productType":"2",
# 			"brand":"지오다노",
# 			"maker":"지오다노",
# 			"category1":"패션의류",
# 			"category2":"남성의류",
# 			"category3":"티셔츠",
# 			"category4":""
# 		}
# 	]
# }
# <class 'str'>

# %%
import json
import pandas as pd

json_input = json.loads(keyword_input)
# print(json_input)
print(json.dumps(json_input))
# shop_review=pd.read_json(path_or_buf="", orient=json_input)
with open("naver_shopping.json", 'w', encoding="utf-8") as json_file:
    json.dump(json_input, json_file, ensure_ascii=False, sort_keys=True, indent="\t")
# Out:
# {"lastBuildDate": "Mon, 10 Jun 2024 11:21:16 +0900", "total": 19126815, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/catalog/40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "34990", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/catalog/46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://smartstore.naver.com/main/products/8156962354", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://smartstore.naver.com/main/products/8927950803", "image": "https://shopping-phinf.pstatic.net/main_8647245/86472451126.1.jpg", "lprice": "4890", "hprice": "", "mallName": "\ub85c\ud30c\uc81c", "productId": "86472451126", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/catalog/38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uae30\ub2a5\uc131 <b>\ubc18\ud314</b> \ucfe8<b>\ud2f0\uc154\uce20</b> \ub0a8\uc790 \ubb34\uc9c0 \ucfe8\ub860 \ud5ec\uc2a4 \ub0c9\uac10 \ucfe8\ub9c1 \uc6b4\ub3d9 <b>\ud2f0\uc154\uce20</b>", "link": "https://smartstore.naver.com/main/products/6280651078", "image": "https://shopping-phinf.pstatic.net/main_8382515/83825153567.7.jpg", "lprice": "5500", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "83825153567", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://smartstore.naver.com/main/products/7074444453", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice" ...

# %%
print(json.dumps(json_input))
# Out:
# {"lastBuildDate": "Mon, 10 Jun 2024 11:21:16 +0900", "total": 19126815, "start": 1, "display": 20, "items": [{"title": "\ub0a8\uc5ec\uacf5\uc6a9 \uc2a4\ud22c\uc2dc \ubca0\uc774\uc9c1 \ub85c\uace0 <b>\ubc18\ud314\ud2f0\uc154\uce20</b> BLACKWHITE -", "link": "https://search.shopping.naver.com/catalog/40655140276", "image": "https://shopping-phinf.pstatic.net/main_4065514/40655140276.20240526074654.jpg", "lprice": "34990", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "40655140276", "productType": "1", "brand": "\uc2a4\ud22c\uc2dc", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uc9c0\uc624\ub2e4\ub178 \ucf54\ud2bc \ud53c\ucf00 \ud3f4\ub85c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> 013502", "link": "https://search.shopping.naver.com/catalog/46139137391", "image": "https://shopping-phinf.pstatic.net/main_4613913/46139137391.20240531124510.jpg", "lprice": "11700", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "46139137391", "productType": "1", "brand": "\uc9c0\uc624\ub2e4\ub178", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ubb34\uc9c0\ud2f0 \ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> 17\uc218 32\uc218 \uc624\ubc84\ud54f \ube45\uc0ac\uc774\uc988", "link": "https://smartstore.naver.com/main/products/8156962354", "image": "https://shopping-phinf.pstatic.net/main_8570146/85701462677.3.jpg", "lprice": "5900", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "85701462677", "productType": "2", "brand": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "maker": "\ud504\ub9b0\ud2b8\uc2a4\ud0c0", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "<b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0\ud2f0 \ub0a8\uc790 \uc5ec\ub984 \uae30\ubcf8 \uba74 \uc774\ub108 \ub77c\uc6b4\ub4dc \ube45\uc0ac\uc774\uc988 \ub2e8\uccb4\ud2f0", "link": "https://smartstore.naver.com/main/products/8927950803", "image": "https://shopping-phinf.pstatic.net/main_8647245/86472451126.1.jpg", "lprice": "4890", "hprice": "", "mallName": "\ub85c\ud30c\uc81c", "productId": "86472451126", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub77c\ucf54\uc2a4\ud14c \ub0a8\uc131 \uc2ac\ub9bc\ud54f \uce74\ub77c <b>\ubc18\ud314 \ud2f0\uc154\uce20</b> PH4012", "link": "https://search.shopping.naver.com/catalog/38988916962", "image": "https://shopping-phinf.pstatic.net/main_3898891/38988916962.20240314122523.jpg", "lprice": "43600", "hprice": "", "mallName": "\ub124\uc774\ubc84", "productId": "38988916962", "productType": "1", "brand": "\ub77c\ucf54\uc2a4\ud14c", "maker": "\ub77c\ucf54\uc2a4\ud14c", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\uae30\ub2a5\uc131 <b>\ubc18\ud314</b> \ucfe8<b>\ud2f0\uc154\uce20</b> \ub0a8\uc790 \ubb34\uc9c0 \ucfe8\ub860 \ud5ec\uc2a4 \ub0c9\uac10 \ucfe8\ub9c1 \uc6b4\ub3d9 <b>\ud2f0\uc154\uce20</b>", "link": "https://smartstore.naver.com/main/products/6280651078", "image": "https://shopping-phinf.pstatic.net/main_8382515/83825153567.7.jpg", "lprice": "5500", "hprice": "", "mallName": "FLEX SHOP \ud50c\ub809\uc2a4\uc0f5", "productId": "83825153567", "productType": "2", "brand": "", "maker": "", "category1": "\ud328\uc158\uc758\ub958", "category2": "\ub0a8\uc131\uc758\ub958", "category3": "\ud2f0\uc154\uce20", "category4": ""}, {"title": "\ub0a8\uc790 <b>\ubc18\ud314\ud2f0</b> \ubb34\uc9c0 \ud2f0\uc154\uce20 17\uc218 32\uc218", "link": "https://smartstore.naver.com/main/products/7074444453", "image": "https://shopping-phinf.pstatic.net/main_8461894/84618944775.6.jpg", "lprice" ...

# %% [markdown]
# [Pandas.read_json에 대한 설명](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
import pandas as pd

# %%
# naver_news_shopping.json의 경로를 설정해준다.
df = pd.read_json('naver_shopping.json')
df
# Out:
#     display                                              items  \
# 0        20  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 1        20  {'brand': '지오다노', 'category1': '패션의류', 'catego...
# 2        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 3        20  {'brand': '', 'category1': '패션의류', 'category2'...
# 4        20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 5        20  {'brand': '', 'category1': '패션의류', 'category2'...
# 6        20  {'brand': '프린트스타', 'category1': '패션의류', 'categ...
# 7        20  {'brand': '지프', 'category1': '패션의류', 'category...
# 8        20  {'brand': '라코스테', 'category1': '패션의류', 'catego...
# 9        20  {'brand': '타미힐피거', 'category1': '패션의류', 'categ...
# 10       20  {'brand': '칼하트', 'category1': '패션의류', 'categor...
# 11       20  {'brand': '', 'category1': '패션의류', 'category2'...
# 12       20  {'brand': '커버낫', 'category1': '패션의류', 'categor...
# 13       20  {'brand': '산토초이', 'category1': '패션의류', 'catego...
# 14       20  {'brand': '스투시', 'category1': '패션의류', 'categor...
# 15       20  {'brand': '탑텐', 'category1': '패션의류', 'category...
# 16       20  {'brand': '아디다스', 'category1': '패션의류', 'catego...
# 17       20  {'brand': '메종키츠네', 'category1': '패션의류', 'categ...
# 18       20  {'brand': '폴로랄프로렌', 'category1': '패션의류', 'cate...
# 19       20  {'brand': '지오다노', 'category1': '패션의류', 'catego...
#
#                       lastBuildDate  start     total
# 0   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 1   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 2   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 3   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 4   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 5   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 6   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 7   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 8   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 9   Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 10  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 11  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 12  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 13  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 14  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 15  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 16  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 17  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 18  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815
# 19  Mon, 10 Jun 2024 11:21:16 +0900      1  19126815

# %% [markdown]
# - 문제 발생! item 항목에 brand category등 분류가 안되게 들어갔음.
# - Parsing을 해줘야하는데 어떻게 해야하는지 감이 안잡힘...\
# - `rename`을 써줘야하나 일단 columns들을 영어변수로 바꿔서 편리하게 해보자

# %% [markdown]
# - column: 상품id, 상품명, 제조사, 최저가, 이미지링크, 구매링크
# - df.columns = ["product_id","product_name","brand_name","low_price","img_link","buy_link"]
# - columns 갯수를 넘어가므로 일단 만들어두고 JSON file의 key value 부분을 columns로 쓰는 방법에 대해서 고민을 해보자.
# - 1. rename에 대한 방법
# - 2. set_axis에 대한 방법  [set_axis](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html)
# - 3. pivot_table에 대한 방법 - item열에 있는 것을 columns로 바꾼다는 아이디어 [Pivot_table](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot_table.html#pandas.DataFrame.pivot_table)

# %%
# shopping_review = df["items"].pivot_table(columns="productId","title","brand","lprice","image","link")

# %% [markdown]
# - concat에 대해서 찾아보다가 to_frame()함수에 대해서 찾음 [concat/to_frame()](https://pandas.pydata.org/docs/reference/api/pandas.concat.html)

# %%
# to_frame()
item_reviews = df["items"].to_frame()

# %% [markdown]
# [json_normalize 문서](https://pandas.pydata.org/docs/reference/api/pandas.json_normalize.html#pandas-json-normalize)

# %%
# 문제 해결
# json_normalize() 함수를 써야함.
from pandas import json_normalize

shopping_info = json_normalize(json_input["items"])
shopping_info
# Out:
#                                                 title  \
# 0           남여공용 스투시 베이직 로고 <b>반팔티셔츠</b> BLACKWHITE -
# 1                  지오다노 코튼 피케 폴로 <b>반팔 티셔츠</b> 013502
# 2                  무지티 남자 <b>반팔티</b> 17수 32수 오버핏 빅사이즈
# 3           <b>반팔티</b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티
# 4                 라코스테 남성 슬림핏 카라 <b>반팔 티셔츠</b> PH4012
# 5   기능성 <b>반팔</b> 쿨<b>티셔츠</b> 남자 무지 쿨론 헬스 냉감 쿨링 운동...
# 6                        남자 <b>반팔티</b> 무지 티셔츠 17수 32수
# 7               지프 남성 소로나 <b>반팔</b> 라운드 <b>티셔츠</b> 4종
# 8                  라코스테 <b>반팔티</b> 크루넥 베이직 라운드 여름 티셔츠
# 9                        타미힐피거 커플 여름 PK <b>반팔</b> 카라티
# 10                       칼하트 K87 워크웨어 포켓 <b>반팔티셔츠</b>
# 11                남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 <b>반팔티</b>
# 12                 커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠</b>
# 13  쿨티셔츠 냉감 기능성 라운드 <b>반팔티</b> 긴팔 남자 여름 남성 봄 스판 냉장...
# 14  스투시 스투시 멜티드 플라워 돌리 월드투어 트라이브 키튼 아워레가시 피그먼트 <b>...
# 15            탑텐 남성 쿨에어 코튼 <b>반팔 티</b> 오버핏 MSD2TS1001
# 16          (매장판) 아디다스 <b>반팔티</b> 기능성 쿨 <b>반팔 티셔츠</b>
# 17             메종키츠네 <b>반팔티</b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅
# 18                    폴로<b>반팔티</b> 폴로 랄프로렌 라운드 여름 티셔츠
# 19                 지오다노카라티 피케 폴로티 <b>반팔티셔츠</b> 014502
#
#                                                  link  \
# 0   https://search.shopping.naver.com/catalog/4065...
# 1   https://search.shopping.naver.com/catalog/4613...
# 2   https://smartstore.naver.com/main/products/815...
# 3   https://smartstore.naver.com/main/products/892...
# 4   https://search.shopping.naver.com/catalog/3898...
# 5   https://smartstore.naver.com/main/products/628...
# 6   https://smartstore.naver.com/main/products/707...
# 7   https://search.shopping.naver.com/catalog/4690...
# 8   https://smartstore.naver.com/main/products/955...
# 9   https://search.shopping.naver.com/catalog/4718...
# 10  https://search.shopping.naver.com/catalog/4491...
# 11  https://smartstore.naver.com/main/products/450...
# 12  https://search.shopping.naver.com/catalog/3170...
# 13  https://smartstore.naver.com/main/products/767...
# 14  https://search.shopping.naver.com/catalog/4387...
# 15  https://search.shopping.naver.com/catalog/4517...
# 16  https://smartstore.naver.com/main/products/660...
# 17  https://smartstore.naver.com/main/products/488...
# 18  https://smartstore.naver.com/main/products/817...
# 19  https://shopping.naver.com/outlink/itemdetail/...
#
#                                                 image lprice hprice  \
# 0   https://shopping-phinf.pstatic.net/main_406551...  34990
# 1   https://shopping-phinf.pstatic.net/main_461391...  11700
# 2   https://shopping-phinf.pstatic.net/main_857014...   5900
# 3   https://shopping-phinf.pstatic.net/main_864724...   4890
# 4   https://shopping-phinf.pstatic.net/main_389889...  43600
# 5   https://shopping-phinf.pstatic.net/main_838251...   5500
# 6   https://shopping-phinf.pstatic.net/main_846189...   5900
# 7   https://shopping-phinf.pstatic.net/main_469003...  32900
# 8   https://shopping-phinf.pstatic.net/main_870997...  34900
# 9   https://shopping-phinf.pstatic.net/main_471817...  29580
# 10  https://shopping-phinf.pstatic.net/main_449108...  21900
# 11  https://shopping-phinf.pstatic.net/main_820470...  19800
# 12  https://shopping-phinf.pstatic.net/main_317099...  32520
# 13  https://shopping-phinf.pstatic.net/main_852214...   4700
# 14  https://shopping-phinf.pstatic.net/main_438758...  33800
# 15  https://shopping-phinf.pstatic.net/main_451719...  14930
# 16  https://shopping-phinf.pstatic.net/main_841464...  11000
# 17  https://shopping-phinf.pstatic.net/main_824259...  91000
# 18  https://shopping-phinf.pstatic.net/main_857242...  25600
# 19  https://shopping-phinf.pstatic.net/main_877190...  16920
#
#           mallName    productId productType   brand   maker category1  \
# 0              네이버  40655140276           1     스투시              패션의류
# 1              네이버  46139137391           1    지오다노              패션의류
# 2   FLEX SHOP 플렉스샵  85701462677           2   프린트스타   프린트스타      패션의류
# 3              로파제  86472451126           2                      패션의류
# 4              네이버  38988916962           1    라코스테    라코스테      패션의류
# 5   FLEX SHOP 플렉스샵  83825153567           2                      패션의류
# 6              후리찌  84618944775           2   프린트스타   프린트스타      패션의류
# 7              네이버  46900319035           1      지프              패션의류
# 8         퀵스마트 스토어  87099744126           2    라코스테    라코스테      패션의류
# 9              네이버  47181793552           1   타미힐피거              패션의류
# 10             네이버  44910813703           1     칼하트              패션의류
# 11            에프오유  82047079376           2                      패션의류
# 12             네이버  31709924618           1     커버낫              패션의류
# 13            산토초이  85221485675           2    산토초이              패션의류
# 14             네이버  43875890304           1     스투시              패션의류
# 15             네이버  45171972049           1      탑텐              패션의류
# 16           스니커오프  84146415087           2    아디다스    아디다스      패션의류
# 17         브랜드리퍼블릭  82425930806           2   메종키츠네   메종키츠네      패션의류
# 18        퀵스마트 스토어  85724262986           2  폴로랄프로렌  폴로랄프로렌      패션의류
# 19            지오다노  87719064917           2    지오다노    지오다노      패션의류
#
#    category2 category3 category4
# 0       남성의류       티셔츠
# 1       남성의류       티셔츠
# 2       남성의류       티셔츠
# 3       남성의류       티셔츠
# 4       남성의류       티셔츠
# 5       남성의류       티셔츠
# 6       남성의류       티셔츠
# 7       남성의류       티셔츠
# 8       남성의류       티셔츠
# 9       남성의류       티셔츠
# 10      남성의류       티셔츠
# 11      남성의류       티셔츠
# 12      남성의류       티셔츠
# 13      남성의류       티셔츠
# 14      남성의류       티셔츠
# 15      남성의류       티셔츠
# 16      남성의류       티셔츠
# 17      남성의류       티셔츠
# 18      남성의류       티셔츠
# 19      남성의류       티셔츠

# %%
# pivot_table을 이용해서 내가 원하는 항목만 추리기 -> pivot_table은 내가 원하는 데이터를 읽고 싶을 때 쓴다.
# loc를 써서 나타낸다.

shopping_data = shopping_info.loc[:, ["productId","title","brand","lprice","image","link"]]

shopping_data
# Out:
#       productId                                              title   brand  \
# 0   40655140276          남여공용 스투시 베이직 로고 <b>반팔티셔츠</b> BLACKWHITE -     스투시
# 1   46139137391                 지오다노 코튼 피케 폴로 <b>반팔 티셔츠</b> 013502    지오다노
# 2   85701462677                 무지티 남자 <b>반팔티</b> 17수 32수 오버핏 빅사이즈   프린트스타
# 3   86472451126          <b>반팔티</b> 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티
# 4   38988916962                라코스테 남성 슬림핏 카라 <b>반팔 티셔츠</b> PH4012    라코스테
# 5   83825153567  기능성 <b>반팔</b> 쿨<b>티셔츠</b> 남자 무지 쿨론 헬스 냉감 쿨링 운동...
# 6   84618944775                       남자 <b>반팔티</b> 무지 티셔츠 17수 32수   프린트스타
# 7   46900319035              지프 남성 소로나 <b>반팔</b> 라운드 <b>티셔츠</b> 4종      지프
# 8   87099744126                 라코스테 <b>반팔티</b> 크루넥 베이직 라운드 여름 티셔츠    라코스테
# 9   47181793552                       타미힐피거 커플 여름 PK <b>반팔</b> 카라티   타미힐피거
# 10  44910813703                       칼하트 K87 워크웨어 포켓 <b>반팔티셔츠</b>     칼하트
# 11  82047079376                남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 <b>반팔티</b>
# 12  31709924618                 커버낫 쿨코튼 2-PACK 베츠 기본 <b>반팔 티셔츠</b>     커버낫
# 13  85221485675  쿨티셔츠 냉감 기능성 라운드 <b>반팔티</b> 긴팔 남자 여름 남성 봄 스판 냉장...    산토초이
# 14  43875890304  스투시 스투시 멜티드 플라워 돌리 월드투어 트라이브 키튼 아워레가시 피그먼트 <b>...     스투시
# 15  45171972049            탑텐 남성 쿨에어 코튼 <b>반팔 티</b> 오버핏 MSD2TS1001      탑텐
# 16  84146415087          (매장판) 아디다스 <b>반팔티</b> 기능성 쿨 <b>반팔 티셔츠</b>    아디다스
# 17  82425930806             메종키츠네 <b>반팔티</b> 카라티 더블 폭스헤드 칠랙스 핸드라이팅   메종키츠네
# 18  85724262986                    폴로<b>반팔티</b> 폴로 랄프로렌 라운드 여름 티셔츠  폴로랄프로렌
# 19  87719064917                 지오다노카라티 피케 폴로티 <b>반팔티셔츠</b> 014502    지오다노
#
#    lprice                                              image  \
# 0   34990  https://shopping-phinf.pstatic.net/main_406551...
# 1   11700  https://shopping-phinf.pstatic.net/main_461391...
# 2    5900  https://shopping-phinf.pstatic.net/main_857014...
# 3    4890  https://shopping-phinf.pstatic.net/main_864724...
# 4   43600  https://shopping-phinf.pstatic.net/main_389889...
# 5    5500  https://shopping-phinf.pstatic.net/main_838251...
# 6    5900  https://shopping-phinf.pstatic.net/main_846189...
# 7   32900  https://shopping-phinf.pstatic.net/main_469003...
# 8   34900  https://shopping-phinf.pstatic.net/main_870997...
# 9   29580  https://shopping-phinf.pstatic.net/main_471817...
# 10  21900  https://shopping-phinf.pstatic.net/main_449108...
# 11  19800  https://shopping-phinf.pstatic.net/main_820470...
# 12  32520  https://shopping-phinf.pstatic.net/main_317099...
# 13   4700  https://shopping-phinf.pstatic.net/main_852214...
# 14  33800  https://shopping-phinf.pstatic.net/main_438758...
# 15  14930  https://shopping-phinf.pstatic.net/main_451719...
# 16  11000  https://shopping-phinf.pstatic.net/main_841464...
# 17  91000  https://shopping-phinf.pstatic.net/main_824259...
# 18  25600  https://shopping-phinf.pstatic.net/main_857242...
# 19  16920  https://shopping-phinf.pstatic.net/main_877190...
#
#                                                  link
# 0   https://search.shopping.naver.com/catalog/4065...
# 1   https://search.shopping.naver.com/catalog/4613...
# 2   https://smartstore.naver.com/main/products/815...
# 3   https://smartstore.naver.com/main/products/892...
# 4   https://search.shopping.naver.com/catalog/3898...
# 5   https://smartstore.naver.com/main/products/628...
# 6   https://smartstore.naver.com/main/products/707...
# 7   https://search.shopping.naver.com/catalog/4690...
# 8   https://smartstore.naver.com/main/products/955...
# 9   https://search.shopping.naver.com/catalog/4718...
# 10  https://search.shopping.naver.com/catalog/4491...
# 11  https://smartstore.naver.com/main/products/450...
# 12  https://search.shopping.naver.com/catalog/3170...
# 13  https://smartstore.naver.com/main/products/767...
# 14  https://search.shopping.naver.com/catalog/4387...
# 15  https://search.shopping.naver.com/catalog/4517...
# 16  https://smartstore.naver.com/main/products/660...
# 17  https://smartstore.naver.com/main/products/488...
# 18  https://smartstore.naver.com/main/products/817...
# 19  https://shopping.naver.com/outlink/itemdetail/...

# %%
shopping_data["title"] = shopping_data["title"].str.replace('<b>','')
shopping_data["title"] = shopping_data["title"].str.replace('</b>','')

# %%
shopping_data1 = shopping_data.set_index("productId")

shopping_data1
# Out:
#                                                          title   brand lprice  \
# productId
# 40655140276                 남여공용 스투시 베이직 로고 반팔티셔츠 BLACKWHITE -     스투시  34990
# 46139137391                        지오다노 코튼 피케 폴로 반팔 티셔츠 013502    지오다노  11700
# 85701462677                        무지티 남자 반팔티 17수 32수 오버핏 빅사이즈   프린트스타   5900
# 86472451126                 반팔티 무지티 남자 여름 기본 면 이너 라운드 빅사이즈 단체티           4890
# 38988916962                       라코스테 남성 슬림핏 카라 반팔 티셔츠 PH4012    라코스테  43600
# 83825153567               기능성 반팔 쿨티셔츠 남자 무지 쿨론 헬스 냉감 쿨링 운동 티셔츠           5500
# 84618944775                              남자 반팔티 무지 티셔츠 17수 32수   프린트스타   5900
# 46900319035                            지프 남성 소로나 반팔 라운드 티셔츠 4종      지프  32900
# 87099744126                        라코스테 반팔티 크루넥 베이직 라운드 여름 티셔츠    라코스테  34900
# 47181793552                              타미힐피거 커플 여름 PK 반팔 카라티   타미힐피거  29580
# 44910813703                              칼하트 K87 워크웨어 포켓 반팔티셔츠     칼하트  21900
# 82047079376                       남자 오버핏 박스 반팔 여름 티셔츠 빅사이즈 반팔티          19800
# 31709924618                        커버낫 쿨코튼 2-PACK 베츠 기본 반팔 티셔츠     커버낫  32520
# 85221485675   쿨티셔츠 냉감 기능성 라운드 반팔티 긴팔 남자 여름 남성 봄 스판 냉장고 반목 빅사이즈    산토초이   4700
# 43875890304  스투시 스투시 멜티드 플라워 돌리 월드투어 트라이브 키튼 아워레가시 피그먼트 반팔 티셔츠     스투시  33800
# 45171972049                   탑텐 남성 쿨에어 코튼 반팔 티 오버핏 MSD2TS1001      탑텐  14930
# 84146415087                        (매장판) 아디다스 반팔티 기능성 쿨 반팔 티셔츠    아디다스  11000
# 82425930806                    메종키츠네 반팔티 카라티 더블 폭스헤드 칠랙스 핸드라이팅   메종키츠네  91000
# 85724262986                           폴로반팔티 폴로 랄프로렌 라운드 여름 티셔츠  폴로랄프로렌  25600
# 87719064917                        지오다노카라티 피케 폴로티 반팔티셔츠 014502    지오다노  16920
#
#                                                          image  \
# productId
# 40655140276  https://shopping-phinf.pstatic.net/main_406551...
# 46139137391  https://shopping-phinf.pstatic.net/main_461391...
# 85701462677  https://shopping-phinf.pstatic.net/main_857014...
# 86472451126  https://shopping-phinf.pstatic.net/main_864724...
# 38988916962  https://shopping-phinf.pstatic.net/main_389889...
# 83825153567  https://shopping-phinf.pstatic.net/main_838251...
# 84618944775  https://shopping-phinf.pstatic.net/main_846189...
# 46900319035  https://shopping-phinf.pstatic.net/main_469003...
# 87099744126  https://shopping-phinf.pstatic.net/main_870997...
# 47181793552  https://shopping-phinf.pstatic.net/main_471817...
# 44910813703  https://shopping-phinf.pstatic.net/main_449108...
# 82047079376  https://shopping-phinf.pstatic.net/main_820470...
# 31709924618  https://shopping-phinf.pstatic.net/main_317099...
# 85221485675  https://shopping-phinf.pstatic.net/main_852214...
# 43875890304  https://shopping-phinf.pstatic.net/main_438758...
# 45171972049  https://shopping-phinf.pstatic.net/main_451719...
# 84146415087  https://shopping-phinf.pstatic.net/main_841464...
# 82425930806  https://shopping-phinf.pstatic.net/main_824259...
# 85724262986  https://shopping-phinf.pstatic.net/main_857242...
# 87719064917  https://shopping-phinf.pstatic.net/main_877190...
#
#                                                           link
# productId
# 40655140276  https://search.shopping.naver.com/catalog/4065...
# 46139137391  https://search.shopping.naver.com/catalog/4613...
# 85701462677  https://smartstore.naver.com/main/products/815...
# 86472451126  https://smartstore.naver.com/main/products/892...
# 38988916962  https://search.shopping.naver.com/catalog/3898...
# 83825153567  https://smartstore.naver.com/main/products/628...
# 84618944775  https://smartstore.naver.com/main/products/707...
# 46900319035  https://search.shopping.naver.com/catalog/4690...
# 87099744126  https://smartstore.naver.com/main/products/955...
# 47181793552  https://search.shopping.naver.com/catalog/4718...
# 44910813703  https://search.shopping.naver.com/catalog/4491...
# 82047079376  https://smartstore.naver.com/main/products/450...
# 31709924618  https://search.shopping.naver.com/catalog/3170...
# 85221485675  https://smartstore.naver.com/main/products/767...
# 43875890304  https://search.shopping.naver.com/catalog/4387...
# 45171972049  https://search.shopping.naver.com/catalog/4517...
# 84146415087  https://smartstore.naver.com/main/products/660...
# 82425930806  https://smartstore.naver.com/main/products/488...
# 85724262986  https://smartstore.naver.com/main/products/817...
# 87719064917  https://shopping.naver.com/outlink/itemdetail/...

# %%
# to_csv() 함수를 써서 경로를 설정한 후 csv파일 만들기
shopping_data1.to_csv("C:/Users/pps/Desktop/TIL/shopping_data.csv")

# %%
# shopping_data.to_csv("C:/Users/pps/Desktop/TIL/shopping_temp_data.csv")

# %%
# 모든 과정을 함수에 담기

import os
import urllib.parse
import urllib.request
import json
import pandas as pd

from dotenv import load_dotenv

load_dotenv()

def searh_naver_shopping(keyword, json_path, csv_path):
    
    client_id = os.getenv("NAVER_CLIENT_ID")
    client_key = os.getenv("NAVER_CLIENT_KEY")
    
    encrypt_text = urllib.parse.quote(keyword)
    
    url = "https://openapi.naver.com/v1/search/shop?query="+ encrypt_text +"&display=20&exclude=used:rental"

    req_url = urllib.request.Request(url)
    
    req_url.add_header("X-Naver-Client-Id", client_id)
    req_url.add_header("X-Naver-Client-Secret", client_key)
    
    response = urllib.request.urlopen(req_url)
    resp_code = response.getcode()

    if resp_code == 200:
        shop_output = response.read().decode("utf-8")
    else:
        shop_output = "Error" + resp_code
    
    
    json_input = json.loads(shop_output)
    with open(json_path, 'w', encoding="utf-8") as json_file:
        json.dump(json_input, json_file, ensure_ascii=False, sort_keys=True, indent="\t")
        
    shopping_info = json_normalize(json_input["items"])
    shopping_data = shopping_info.loc[:, ["productId","title","brand","lprice","image","link"]]
    # shopping_data.replace('<b>|</b>','', regex=True, inplace=True) # 정규식을 이용한 문자열 제거
    shopping_data["title"] = shopping_data["title"].str.replace('<b>','')
    shopping_data["title"] = shopping_data["title"].str.replace('</b>','')
    shopping_data1 = shopping_data.set_index("productId")
    shopping_data1.to_csv(csv_path)
    
    
searh_naver_shopping("바지","pants_shopping.json","C:/Users/pps/Desktop/TIL/pants_shopping_info.csv")

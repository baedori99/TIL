# %%
import pandas as pd

# %%
# DataFrame 나타내기
# index column을 0으로 하여 안나타내기
dust_reviews = pd.read_csv("C:/Users/pps/Desktop/배정환(인턴)/기간별_일평균_대기환경_정보_2023년.csv", encoding='cp949',index_col=0)

dust_reviews
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230101  동남권  강남구        0.0240     0.0240          0.60        0.0040
# 20230101  동남권  강동구        0.0270     0.0170          0.70        0.0030
# 20230101  동북권  강북구           NaN     0.0260          0.70        0.0040
# 20230101  서남권  강서구        0.0210     0.0250          0.60        0.0040
# 20230101  서남권  관악구        0.0250     0.0200          0.60        0.0030
# ...       ...  ...           ...        ...           ...           ...
# 20231231  도심권  용산구        0.0286     0.0146          0.78        0.0025
# 20231231  서북권  은평구        0.0172     0.0178          1.12        0.0025
# 20231231  도심권  종로구        0.0238     0.0180          0.73        0.0029
# 20231231  도심권   중구        0.0261     0.0179          0.67        0.0028
# 20231231  동북권  중랑구        0.0316     0.0130          0.68        0.0024
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230101       52.0        36.0
# ...

# %%
# Columns 확인하기

dust_reviews.columns
# Out:
# Index(['권역명', '측정소명', '이산화질소농도(ppm)', '오존농도(ppm)', '일산화탄소농도(ppm)',
#        '아황산가스농도(ppm)', '미세먼지(㎍/㎥)', '초미세먼지(㎍/㎥)'],
#       dtype='object')

# %%
# 헹/열 크기 확인
dust_reviews.shape
# Out:
# (9125, 8)

# %%
dust_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9125 entries, 20230101 to 20231231
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   권역명           9125 non-null   object
#  1   측정소명          9125 non-null   object
#  2   이산화질소농도(ppm)  9048 non-null   float64
#  3   오존농도(ppm)     9054 non-null   float64
#  4   일산화탄소농도(ppm)  8865 non-null   float64
#  5   아황산가스농도(ppm)  8972 non-null   float64
#  6   미세먼지(㎍/㎥)     9036 non-null   float64
#  7   초미세먼지(㎍/㎥)    9051 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 641.6+ KB

# %%
# 각 column의 데이터 타입 확인하기
dust_reviews.dtypes
# Out:
# 권역명              object
# 측정소명             object
# 이산화질소농도(ppm)    float64
# 오존농도(ppm)       float64
# 일산화탄소농도(ppm)    float64
# 아황산가스농도(ppm)    float64
# 미세먼지(㎍/㎥)       float64
# 초미세먼지(㎍/㎥)      float64
# dtype: object

# %%
# 고유값 개수 확인
dust_reviews.nunique()
# Out:
# 권역명               5
# 측정소명             25
# 이산화질소농도(ppm)    562
# 오존농도(ppm)       705
# 일산화탄소농도(ppm)    115
# 아황산가스농도(ppm)     55
# 미세먼지(㎍/㎥)       190
# 초미세먼지(㎍/㎥)       93
# dtype: int64

# %%
# 권역명 데이터의 고유값 확인
dust_reviews['권역명'].unique()
# Out:
# array(['동남권', '동북권', '서남권', '서북권', '도심권'], dtype=object)

# %%
# 측정소명 데이터의 고유값 확인
dust_reviews['측정소명'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
# 이산화질소농도, 오존농도, 일산화탄소농도, 아황산가스농도, 미세먼지농도, 초미세먼지 농도에 대한 요약
dust_reviews.describe()
# Out:
#        이산화질소농도(ppm)    오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)    미세먼지(㎍/㎥)  \
# count   9048.000000  9054.000000   8865.000000   8972.000000  9036.000000
# mean       0.020384     0.030583      0.451223      0.002813    37.734949
# std        0.011042     0.013847      0.158300      0.000567    26.944100
# min        0.001900     0.002000      0.090000      0.001200     3.000000
# 25%        0.012300     0.020700      0.350000      0.002400    21.000000
# 50%        0.017400     0.029300      0.410000      0.002800    32.000000
# 75%        0.025900     0.039500      0.520000      0.003100    45.000000
# max        0.069600     0.095100      1.410000      0.007900   319.000000
#
#         초미세먼지(㎍/㎥)
# count  9051.000000
# mean     19.660259
# std      13.013382
# min       1.000000
# 25%      11.000000
# 50%      17.000000
# 75%      25.000000
# max     116.000000

# %%
# 처음 5개의 행
dust_reviews.head()
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230101  동남권  강남구         0.024      0.024           0.6         0.004
# 20230101  동남권  강동구         0.027      0.017           0.7         0.003
# 20230101  동북권  강북구           NaN      0.026           0.7         0.004
# 20230101  서남권  강서구         0.021      0.025           0.6         0.004
# 20230101  서남권  관악구         0.025      0.020           0.6         0.003
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230101       52.0        36.0
# 20230101       56.0        43.0
# 20230101       51.0        34.0
# 20230101       62.0        38.0
# 20230101       54.0        35.0

# %%
# 마지막 5개의 행
dust_reviews.tail()
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20231231  도심권  용산구        0.0286     0.0146          0.78        0.0025
# 20231231  서북권  은평구        0.0172     0.0178          1.12        0.0025
# 20231231  도심권  종로구        0.0238     0.0180          0.73        0.0029
# 20231231  도심권   중구        0.0261     0.0179          0.67        0.0028
# 20231231  동북권  중랑구        0.0316     0.0130          0.68        0.0024
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20231231       22.0        15.0
# 20231231       21.0        18.0
# 20231231       22.0        18.0
# 20231231       20.0        18.0
# 20231231       20.0        16.0

# %%
# 측정소명/권역명의 데이터 전체 개수
dust_reviews['측정소명'].value_counts()
# Out:
# 측정소명
# 강남구     365
# 서대문구    365
# 중구      365
# 종로구     365
# 은평구     365
# 용산구     365
# 영등포구    365
# 양천구     365
# 송파구     365
# 성북구     365
# 성동구     365
# 서초구     365
# 마포구     365
# 강동구     365
# 동작구     365
# 동대문구    365
# 도봉구     365
# 노원구     365
# 금천구     365
# 구로구     365
# 광진구     365
# 관악구     365
# 강서구     365
# 강북구     365
# 중랑구     365
# Name: count, dtype: int64

# %%
# 이산화질소농도(ppm)의 결측값 확인하기
dust_reviews.loc[dust_reviews['이산화질소농도(ppm)'].isnull()]
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230101  동북권  강북구           NaN     0.0260          0.70        0.0040
# 20230110  도심권   중구           NaN        NaN           NaN           NaN
# 20230111  도심권   중구           NaN        NaN           NaN           NaN
# 20230112  도심권   중구           NaN        NaN           NaN           NaN
# 20230113  도심권   중구           NaN        NaN           NaN           NaN
# ...       ...  ...           ...        ...           ...           ...
# 20231004  동남권  강동구           NaN        NaN           NaN           NaN
# 20231005  동남권  강동구           NaN        NaN           NaN           NaN
# 20231011  도심권  종로구           NaN        NaN           NaN           NaN
# 20231018  서남권  구로구           NaN     0.0030          0.50        0.0020
# 20231107  동북권  성북구           NaN     0.0272          0.31        0.0021
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230101       51.0        34.0
# ...

# %%
# 이산화질소농도(ppm)의 결측값 확인
dust_reviews.loc[dust_reviews['이산화질소농도(ppm)'].isnull()]
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230101  동북권  강북구           NaN     0.0260          0.70        0.0040
# 20230110  도심권   중구           NaN        NaN           NaN           NaN
# 20230111  도심권   중구           NaN        NaN           NaN           NaN
# 20230112  도심권   중구           NaN        NaN           NaN           NaN
# 20230113  도심권   중구           NaN        NaN           NaN           NaN
# ...       ...  ...           ...        ...           ...           ...
# 20231004  동남권  강동구           NaN        NaN           NaN           NaN
# 20231005  동남권  강동구           NaN        NaN           NaN           NaN
# 20231011  도심권  종로구           NaN        NaN           NaN           NaN
# 20231018  서남권  구로구           NaN     0.0030          0.50        0.0020
# 20231107  동북권  성북구           NaN     0.0272          0.31        0.0021
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230101       51.0        34.0
# ...

# %%
# 이산화질소농도(ppm)의 결측값 개수 확인
dust_reviews['이산화질소농도(ppm)'].isnull().sum()
# Out:
# 77

# %%
# 오존농도(ppm)의 결측값 확인
dust_reviews.loc[dust_reviews['오존농도(ppm)'].isnull()]
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230110  도심권   중구           NaN        NaN           NaN           NaN
# 20230111  도심권   중구           NaN        NaN           NaN           NaN
# 20230112  도심권   중구           NaN        NaN           NaN           NaN
# 20230113  도심권   중구           NaN        NaN           NaN           NaN
# 20230114  도심권   중구           NaN        NaN           NaN           NaN
# ...       ...  ...           ...        ...           ...           ...
# 20231011  도심권  종로구           NaN        NaN           NaN           NaN
# 20231124  동남권  강남구        0.0103        NaN          0.29        0.0028
# 20231227  서남권  구로구        0.0394        NaN          1.05        0.0033
# 20231228  서남권  구로구        0.0427        NaN          0.95        0.0032
# 20231229  서남권  구로구        0.0333        NaN          0.83        0.0030
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230110        NaN         NaN
# ...

# %%
dust_reviews['오존농도(ppm)'].isnull().sum()
# Out:
# 71

# %%
# 일산화탄소농도(ppm)의 결측값 확인
dust_reviews.loc[dust_reviews['일산화탄소농도(ppm)'].isnull()]
# Out:
#           권역명  측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230110  도심권    중구           NaN        NaN           NaN           NaN
# 20230111  도심권    중구           NaN        NaN           NaN           NaN
# 20230112  동남권   서초구        0.0587     0.0041           NaN        0.0031
# 20230112  도심권    중구           NaN        NaN           NaN           NaN
# 20230113  동남권   서초구        0.0415     0.0046           NaN        0.0027
# ...       ...   ...           ...        ...           ...           ...
# 20231212  동북권   도봉구        0.0063     0.0255           NaN        0.0025
# 20231217  동북권   광진구        0.0097     0.0321           NaN        0.0016
# 20231217  서북권  서대문구        0.0074     0.0330           NaN           NaN
# 20231217  서북권   은평구        0.0091     0.0259           NaN        0.0028
# 20231221  동북권   도봉구        0.0070     0.0336           NaN        0.0021
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230110        NaN         NaN
# ...

# %%
# 일산화탄소(ppm)의 결측값 개수 확인
dust_reviews['일산화탄소농도(ppm)'].isnull().sum()
# Out:
# 260

# %%
# 아황산가스농도(ppm)의 결측값 확인
dust_reviews['아황산가스농도(ppm)'].fillna("Unknown")
# Out:
# 측정일시
# 20230101     0.004
# 20230101     0.003
# 20230101     0.004
# 20230101     0.004
# 20230101     0.003
#              ...
# 20231231    0.0025
# 20231231    0.0025
# 20231231    0.0029
# 20231231    0.0028
# 20231231    0.0024
# Name: 아황산가스농도(ppm), Length: 9125, dtype: object

# %%
# 아황산가스농도(ppm)의 결측값 개수 확인
dust_reviews['아황산가스농도(ppm)'].isnull().sum()
# Out:
# 153

# %%
# 미세먼지 농도(㎍/㎥)의 결측값 확인
dust_reviews['미세먼지(㎍/㎥)'].fillna("Unknown")
# Out:
# 측정일시
# 20230101    52.0
# 20230101    56.0
# 20230101    51.0
# 20230101    62.0
# 20230101    54.0
#             ...
# 20231231    22.0
# 20231231    21.0
# 20231231    22.0
# 20231231    20.0
# 20231231    20.0
# Name: 미세먼지(㎍/㎥), Length: 9125, dtype: object

# %%
# 미세먼지(㎍/㎥) 결측값 개수 확인하기
dust_reviews['미세먼지(㎍/㎥)'].isnull().sum()
# Out:
# 89

# %%
# 초미세먼지(㎍/㎥) 결측값 확인
dust_reviews['초미세먼지(㎍/㎥)'].fillna("Unknown")
# Out:
# 측정일시
# 20230101    36.0
# 20230101    43.0
# 20230101    34.0
# 20230101    38.0
# 20230101    35.0
#             ...
# 20231231    15.0
# 20231231    18.0
# 20231231    18.0
# 20231231    18.0
# 20231231    16.0
# Name: 초미세먼지(㎍/㎥), Length: 9125, dtype: object

# %%
# 초미세먼지(㎍/㎥) 결측값 개수 확인하기
dust_reviews['초미세먼지(㎍/㎥)'].isnull().sum()
# Out:
# 74

# %%
# # 결측치 값만 가지고 오기
# # 결측치 값이 0인것은 뺌
# dust_reviews.isnull().sum().sort_values(ascending=False)[dust_reviews.isnull().sum().sort_values(ascending=False) != 0]

# %%
# 이산화질소농도 연평균 구하기
dust_reviews['이산화질소농도(ppm)'].mean()
# Out:
# 0.020383963306808136

# %%
# 측정소명 별 이산화질소농도 평균 구하기
dust_reviews.groupby('측정소명')['이산화질소농도(ppm)'].mean()
# Out:
# 측정소명
# 강남구     0.022652
# 강동구     0.019225
# 강북구     0.014332
# 강서구     0.021501
# 관악구     0.022781
# 광진구     0.020132
# 구로구     0.017323
# 금천구     0.021317
# 노원구     0.020016
# 도봉구     0.015851
# 동대문구    0.020561
# 동작구     0.020923
# 마포구     0.022338
# 서대문구    0.016401
# 서초구     0.021520
# 성동구     0.020838
# 성북구     0.021962
# 송파구     0.024569
# 양천구     0.021915
# 영등포구    0.023404
# 용산구     0.022224
# 은평구     0.015573
# 종로구     0.020346
# 중구      0.021785
# 중랑구     0.020217
# Name: 이산화질소농도(ppm), dtype: float64

# %%
# 측정소명 별 오존농도 평균 구하기
dust_reviews.groupby('측정소명')['오존농도(ppm)'].mean()
# Out:
# 측정소명
# 강남구     0.031112
# 강동구     0.026126
# 강북구     0.033944
# 강서구     0.031427
# 관악구     0.031043
# 광진구     0.029028
# 구로구     0.027427
# 금천구     0.029917
# 노원구     0.029841
# 도봉구     0.033545
# 동대문구    0.032118
# 동작구     0.033615
# 마포구     0.032020
# 서대문구    0.032417
# 서초구     0.028135
# 성동구     0.030303
# 성북구     0.028907
# 송파구     0.029006
# 양천구     0.029445
# 영등포구    0.030342
# 용산구     0.030978
# 은평구     0.029524
# 종로구     0.032152
# 중구      0.031855
# 중랑구     0.030276
# Name: 오존농도(ppm), dtype: float64

# %%
# 측정소명 별 일산화탄소농도 평균 구하기
dust_reviews.groupby('측정소명')['일산화탄소농도(ppm)'].mean()
# Out:
# 측정소명
# 강남구     0.411068
# 강동구     0.425926
# 강북구     0.440685
# 강서구     0.478712
# 관악구     0.488685
# 광진구     0.461957
# 구로구     0.379890
# 금천구     0.444411
# 노원구     0.460575
# 도봉구     0.498365
# 동대문구    0.461191
# 동작구     0.403890
# 마포구     0.463863
# 서대문구    0.492213
# 서초구     0.413333
# 성동구     0.391863
# 성북구     0.496768
# 송파구     0.465315
# 양천구     0.473178
# 영등포구    0.447857
# 용산구     0.480575
# 은평구     0.477572
# 종로구     0.488352
# 중구      0.442710
# 중랑구     0.397123
# Name: 일산화탄소농도(ppm), dtype: float64

# %%
# 측정소명 별 아황산가스농도 평균 구하기
dust_reviews.groupby('측정소명')['아황산가스농도(ppm)'].mean()
# Out:
# 측정소명
# 강남구     0.003165
# 강동구     0.002581
# 강북구     0.002324
# 강서구     0.002982
# 관악구     0.002865
# 광진구     0.002643
# 구로구     0.002667
# 금천구     0.003024
# 노원구     0.002698
# 도봉구     0.002641
# 동대문구    0.003212
# 동작구     0.002635
# 마포구     0.002901
# 서대문구    0.003196
# 서초구     0.002816
# 성동구     0.002750
# 성북구     0.002708
# 송파구     0.002584
# 양천구     0.002888
# 영등포구    0.002819
# 용산구     0.003147
# 은평구     0.002628
# 종로구     0.003122
# 중구      0.002910
# 중랑구     0.002437
# Name: 아황산가스농도(ppm), dtype: float64

# %%
# 측정소 별 미세먼지농도 구하기
dust_reviews.groupby('측정소명')['미세먼지(㎍/㎥)'].mean()
# Out:
# 측정소명
# 강남구     37.260274
# 강동구     39.266667
# 강북구     37.821918
# 강서구     42.134247
# 관악구     41.611570
# 광진구     36.310440
# 구로구     39.482094
# 금천구     36.090411
# 노원구     38.394521
# 도봉구     35.016529
# 동대문구    38.931507
# 동작구     37.509589
# 마포구     35.170799
# 서대문구    34.491667
# 서초구     40.715068
# 성동구     37.575342
# 성북구     38.457300
# 송파구     40.309589
# 양천구     39.547945
# 영등포구    36.346154
# 용산구     39.523416
# 은평구     36.176796
# 종로구     36.002747
# 중구      32.478125
# 중랑구     36.126374
# Name: 미세먼지(㎍/㎥), dtype: float64

# %%
# 측정소 별 초미세먼지농도 구하기
dust_reviews.groupby('측정소명')['초미세먼지(㎍/㎥)'].mean()
# Out:
# 측정소명
# 강남구     19.391781
# 강동구     20.261494
# 강북구     19.265753
# 강서구     19.235616
# 관악구     20.352617
# 광진구     18.679452
# 구로구     18.673973
# 금천구     20.353425
# 노원구     21.112637
# 도봉구     18.607143
# 동대문구    19.657534
# 동작구     20.646409
# 마포구     20.355372
# 서대문구    18.117808
# 서초구     19.490411
# 성동구     18.854795
# 성북구     19.385675
# 송파구     19.909589
# 양천구     20.909589
# 영등포구    19.364384
# 용산구     20.800000
# 은평구     19.151099
# 종로구     19.432877
# 중구      19.479751
# 중랑구     20.038462
# Name: 초미세먼지(㎍/㎥), dtype: float64

# %%
# 측정소 별 이산화질소농도 min, max, mean 구하기
dust_reviews.groupby('측정소명')['이산화질소농도(ppm)'].agg(['min','max','mean'])
# Out:
#          min     max      mean
# 측정소명
# 강남구   0.0065  0.0658  0.022652
# 강동구   0.0046  0.0526  0.019225
# 강북구   0.0038  0.0506  0.014332
# 강서구   0.0059  0.0632  0.021501
# 관악구   0.0070  0.0672  0.022781
# 광진구   0.0057  0.0574  0.020132
# 구로구   0.0048  0.0574  0.017323
# 금천구   0.0047  0.0628  0.021317
# 노원구   0.0051  0.0696  0.020016
# 도봉구   0.0035  0.0519  0.015851
# 동대문구  0.0051  0.0630  0.020561
# 동작구   0.0049  0.0664  0.020923
# 마포구   0.0076  0.0664  0.022338
# 서대문구  0.0033  0.0605  0.016401
# 서초구   0.0053  0.0668  0.021520
# 성동구   0.0047  0.0618  0.020838
# 성북구   0.0035  0.0614  0.021962
# 송파구   0.0069  0.0680  0.024569
# 양천구   0.0066  0.0652  0.021915
# 영등포구  0.0066  0.0684  0.023404
# 용산구   0.0060  0.0611  0.022224
# 은평구   0.0033  0.0512  0.015573
# 종로구   0.0054  0.0680  0.020346
# 중구    0.0072  0.0558  0.021785
# 중랑구   0.0019  0.0634  0.020217

# %%
# 측정소 별 오존농도 min, max, mean 구하기
dust_reviews.groupby('측정소명')['오존농도(ppm)'].agg(['min','max','mean'])
# Out:
#          min     max      mean
# 측정소명
# 강남구   0.0023  0.0736  0.031112
# 강동구   0.0030  0.0624  0.026126
# 강북구   0.0055  0.0834  0.033944
# 강서구   0.0036  0.0876  0.031427
# 관악구   0.0037  0.0810  0.031043
# 광진구   0.0029  0.0687  0.029028
# 구로구   0.0030  0.0640  0.027427
# 금천구   0.0022  0.0722  0.029917
# 노원구   0.0025  0.0805  0.029841
# 도봉구   0.0065  0.0860  0.033545
# 동대문구  0.0034  0.0870  0.032118
# 동작구   0.0041  0.0811  0.033615
# 마포구   0.0033  0.0951  0.032020
# 서대문구  0.0030  0.0827  0.032417
# 서초구   0.0025  0.0711  0.028135
# 성동구   0.0036  0.0752  0.030303
# 성북구   0.0045  0.0758  0.028907
# 송파구   0.0029  0.0737  0.029006
# 양천구   0.0028  0.0778  0.029445
# 영등포구  0.0033  0.0747  0.030342
# 용산구   0.0020  0.0817  0.030978
# 은평구   0.0032  0.0806  0.029524
# 종로구   0.0020  0.0838  0.032152
# 중구    0.0038  0.0775  0.031855
# 중랑구   0.0044  0.0706  0.030276

# %%
# 측정소 별 일산화탄소농도 min, max, mean 구하기

dust_reviews.groupby('측정소명')['일산화탄소농도(ppm)'].agg(['min','max','mean'])
# Out:
#        min   max      mean
# 측정소명
# 강남구   0.20  0.96  0.411068
# 강동구   0.20  1.11  0.425926
# 강북구   0.17  0.94  0.440685
# 강서구   0.24  1.10  0.478712
# 관악구   0.20  1.19  0.488685
# 광진구   0.17  1.34  0.461957
# 구로구   0.18  1.05  0.379890
# 금천구   0.18  1.03  0.444411
# 노원구   0.22  1.08  0.460575
# 도봉구   0.14  1.11  0.498365
# 동대문구  0.17  1.22  0.461191
# 동작구   0.18  1.04  0.403890
# 마포구   0.25  1.08  0.463863
# 서대문구  0.13  1.41  0.492213
# 서초구   0.22  1.02  0.413333
# 성동구   0.18  0.96  0.391863
# 성북구   0.17  1.09  0.496768
# 송파구   0.25  0.98  0.465315
# 양천구   0.25  1.14  0.473178
# 영등포구  0.19  1.03  0.447857
# 용산구   0.25  1.12  0.480575
# 은평구   0.09  1.22  0.477572
# 종로구   0.23  1.20  0.488352
# 중구    0.20  0.95  0.442710
# 중랑구   0.10  0.97  0.397123

# %%
# 측정소 별 아황산가스농도 min, max, mean 구하기
dust_reviews.groupby('측정소명')['아황산가스농도(ppm)'].agg(['min','max','mean'])
# Out:
#          min     max      mean
# 측정소명
# 강남구   0.0023  0.0052  0.003165
# 강동구   0.0019  0.0041  0.002581
# 강북구   0.0016  0.0040  0.002324
# 강서구   0.0019  0.0054  0.002982
# 관악구   0.0016  0.0048  0.002865
# 광진구   0.0013  0.0042  0.002643
# 구로구   0.0018  0.0046  0.002667
# 금천구   0.0016  0.0044  0.003024
# 노원구   0.0016  0.0049  0.002698
# 도봉구   0.0012  0.0037  0.002641
# 동대문구  0.0022  0.0050  0.003212
# 동작구   0.0016  0.0044  0.002635
# 마포구   0.0018  0.0061  0.002901
# 서대문구  0.0013  0.0079  0.003196
# 서초구   0.0017  0.0040  0.002816
# 성동구   0.0015  0.0050  0.002750
# 성북구   0.0017  0.0042  0.002708
# 송파구   0.0016  0.0042  0.002584
# 양천구   0.0015  0.0048  0.002888
# 영등포구  0.0019  0.0054  0.002819
# 용산구   0.0017  0.0052  0.003147
# 은평구   0.0013  0.0040  0.002628
# 종로구   0.0019  0.0050  0.003122
# 중구    0.0020  0.0052  0.002910
# 중랑구   0.0017  0.0038  0.002437

# %%
# 측정소 별 미세먼지농도 min, max, mean 구하기
dust_reviews.groupby('측정소명')['미세먼지(㎍/㎥)'].agg(['min','max','mean'])
# Out:
#       min    max       mean
# 측정소명
# 강남구   3.0  246.0  37.260274
# 강동구   3.0  252.0  39.266667
# 강북구   4.0  269.0  37.821918
# 강서구   5.0  286.0  42.134247
# 관악구   7.0  247.0  41.611570
# 광진구   4.0  253.0  36.310440
# 구로구   3.0  319.0  39.482094
# 금천구   4.0  192.0  36.090411
# 노원구   3.0  257.0  38.394521
# 도봉구   3.0  264.0  35.016529
# 동대문구  5.0  267.0  38.931507
# 동작구   5.0  239.0  37.509589
# 마포구   5.0  215.0  35.170799
# 서대문구  4.0  282.0  34.491667
# 서초구   3.0  288.0  40.715068
# 성동구   5.0  246.0  37.575342
# 성북구   4.0  309.0  38.457300
# 송파구   4.0  291.0  40.309589
# 양천구   5.0  247.0  39.547945
# 영등포구  5.0  222.0  36.346154
# 용산구   5.0  306.0  39.523416
# 은평구   3.0  273.0  36.176796
# 종로구   4.0  267.0  36.002747
# 중구    4.0  234.0  32.478125
# 중랑구   4.0  241.0  36.126374

# %%
# 측정소 별 초미세먼지농도 min, max, mean 구하기
dust_reviews.groupby('측정소명')['초미세먼지(㎍/㎥)'].agg(['min','max','mean'])
# Out:
#       min    max       mean
# 측정소명
# 강남구   1.0   86.0  19.391781
# 강동구   1.0   98.0  20.261494
# 강북구   1.0   77.0  19.265753
# 강서구   1.0   87.0  19.235616
# 관악구   2.0   79.0  20.352617
# 광진구   1.0  116.0  18.679452
# 구로구   1.0   94.0  18.673973
# 금천구   1.0   96.0  20.353425
# 노원구   1.0   91.0  21.112637
# 도봉구   1.0   82.0  18.607143
# 동대문구  1.0   86.0  19.657534
# 동작구   1.0   95.0  20.646409
# 마포구   1.0   96.0  20.355372
# 서대문구  1.0   90.0  18.117808
# 서초구   1.0   94.0  19.490411
# 성동구   2.0   76.0  18.854795
# 성북구   1.0   89.0  19.385675
# 송파구   2.0   84.0  19.909589
# 양천구   1.0   98.0  20.909589
# 영등포구  2.0   95.0  19.364384
# 용산구   2.0   76.0  20.800000
# 은평구   1.0   89.0  19.151099
# 종로구   1.0  101.0  19.432877
# 중구    2.0   98.0  19.479751
# 중랑구   1.0   92.0  20.038462

# %%
# 한글 글꼴 설정
import matplotlib.pyplot as plt
font_path = 'C:/Users/pps/AppData/Local/Microsoft/Windows/Fonts/NanumBarunGothic.ttf'
font_name = plt.matplotlib.font_manager.FontProperties(fname=font_path).get_name()

plt.rcParams['font.family'] = font_name

# %%
import numpy as np

dust_reviews.groupby('측정소명')['초미세먼지(㎍/㎥)'].agg(['min','max','mean']).boxplot()

plt.show()

# %%
Gwangjin_reviewed=dust_reviews[dust_reviews['측정소명'] == '광진구']
Gwangjin_reviewed
# Out:
#           권역명 측정소명  이산화질소농도(ppm)  오존농도(ppm)  일산화탄소농도(ppm)  아황산가스농도(ppm)  \
# 측정일시
# 20230101  동북권  광진구        0.0175     0.0176          0.79        0.0026
# 20230102  동북권  광진구        0.0108     0.0182          0.51        0.0020
# 20230103  동북권  광진구        0.0203     0.0116          0.69        0.0022
# 20230104  동북권  광진구        0.0238     0.0092          0.76        0.0021
# 20230105  동북권  광진구        0.0303     0.0042          0.97        0.0025
# ...       ...  ...           ...        ...           ...           ...
# 20231227  동북권  광진구        0.0574     0.0076          0.87        0.0030
# 20231228  동북권  광진구        0.0488     0.0089          0.84        0.0029
# 20231229  동북권  광진구        0.0442     0.0106          0.72        0.0027
# 20231230  동북권  광진구        0.0341     0.0123          0.67        0.0024
# 20231231  동북권  광진구        0.0346     0.0147          0.84        0.0026
#
#           미세먼지(㎍/㎥)  초미세먼지(㎍/㎥)
# 측정일시
# 20230101       48.0        36.0
# ...

# %%
dust_reviews.groupby(['미세먼지(㎍/㎥)',dust_reviews['측정소명'] == '광진구'])

# %%
Gwangjin_reviewed1 = dust_reviews.loc[dust_reviews['측정소명'] == '광진구',['미세먼지(㎍/㎥)']]

# %%
make_boxplot_gwangjin_reviewd=Gwangjin_reviewed[['측정소명','미세먼지(㎍/㎥)']]
make_boxplot_gwangjin_reviewd
# Out:
#          측정소명  미세먼지(㎍/㎥)
# 측정일시
# 20230101  광진구       48.0
# 20230102  광진구       21.0
# 20230103  광진구       32.0
# 20230104  광진구       34.0
# 20230105  광진구       47.0
# ...       ...        ...
# 20231227  광진구       57.0
# 20231228  광진구       44.0
# 20231229  광진구       40.0
# 20231230  광진구       36.0
# 20231231  광진구       19.0
#
# [365 rows x 2 columns]

# %%
make_boxplot_gwangjin_reviewd.boxplot()

plt.show()

# %% [markdown]
# - Boxplot을 보았을 때 원은 미세먼지 농도 값들을 말하는 거 같고 금이 쳐져있는 것은 최소값과 최댓값을 말하는거 같다.
# - Boxplot의 box는 표준편차나 분산에 관한것을 나타낸거 같다(개인적인 생각)

# %%
make_lineplot = Gwangjin_reviewed[['미세먼지(㎍/㎥)']]

make_lineplot.plot()
plt.show()

# %% [markdown]
# - 위의 그래프를 보고 y축이 미세먼지 농도이고 x축이 측정일시에 대한것임을 알겠지만 측정일시에 대한 값을 보기엔 불편하다
# - 측정일시가 400인 부분이 미세먼지 농도가 제일 높은 것을 보니 계절은 봄으로 생각이 들고 600에서 1000은 미세먼지농도가 제일 낮은 떼로 여름, 가을쪽으로 생각이 든다.

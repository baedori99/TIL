# %% [markdown]
# # 멜론 차트 크롤링

# %% [markdown]
# ### **파싱준비**
# 1. requests or urllib로 html 불러오기
# 2. `soup = BeautifulSoup(html)`

# %% [markdown]
# - 1. requests or urllib로 html 불러오기

# %%
import requests # HTTP 요청을 보내는 모듈

url = "https://www.melon.com/chart/index.htm"

req_header = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'}

res = requests.get(url, headers= req_header)
html = res.text

# %%
from bs4 import BeautifulSoup


soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>멜론차트&gt;TOP100&gt;멜론</title>
# <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
# <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
# <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
# <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
# <meta content="357952407588971" property="fb:app_id"/>
# <meta content="Melon" property="og:title"/>
# <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
# <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
# <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# ...

# %%
temp = soup.find_all('tr',class_='lst50')
print(len(temp))
# Out:
# 50

# %%
test = temp[0]
test.find("div", class_="wrap_song_info").text
# Out:
# '\n\nSupernova\n\n\naespaaespa\n\n'

# %% [markdown]
# - 하나씩 정보를 끌어다와서 확인 후 한곡의 모든 항목이 끝나면 딕셔너리로 모은 뒤 for loop를 사용하여 100개 출력하기

# %%
soup.select('.lst50:nth-child(5)')
# Out:
# [<tr class="lst50" data-song-no="37460832" id="lst50">
#  <td><div class="wrap t_right"><input class="input_check" name="input_check" title="SPOT! (feat. JENNIE) 곡 선택" type="checkbox" value="37460832"/></div></td>
#  <td><div class="wrap t_center"><span class="rank">5</span><span class="none">위</span></div></td>
#  <!-- 차트순위 추가 -->
#  <td><div class="wrap">
#  <span class="rank_wrap" title="순위 동일">
#  <span class="bullet_icons rank_static"><span class="none">순위 동일</span></span>
#  <span class="none">0</span>
#  </span>
#  </div></td>
#  <td><div class="wrap">
#  <a class="image_typeAll" href="javascript:melon.link.goAlbumDetail('11474894');" title="SPOT!">
#  <img alt="SPOT! - 페이지 이동" height="60" onerror="WEBPOCIMG.defaultAlbumImg(this);" src="https://cdnimg.melon.co.kr/cm2/album/images/114/74/894/11474894_20240426103349_500.jpg/melon/resize/120/quality/80/optimize" width="60"/>
#  <span class="bg_album_frame"></span>
#  </a>
#  </div></td>
#  <td><div class="wrap">
# ...

# %%
song_rank50 = soup.findAll('tr', class_='lst50')
song_rank100 = soup.findAll('tr', class_='lst100')

# %%
rank_1 = song_rank50[0]

# %%
rank_1.find('div', class_='wrap t_center').text
# Out:
# '1위'

# %%
rank_1.find('div', class_='wrap_song_info').text
# Out:
# '\n\nSupernova\n\n\naespaaespa\n\n'

# %%
rank_1.find('div', class_ = 'ellipsis rank01').text
# Out:
# '\nSupernova\n'

# %%
rank_1.find('div', class_ = 'ellipsis rank02').text
# Out:
# '\naespaaespa\n'

# %%
rank_1.find('span', class_='cnt').text
# Out:
# '\n총건수\r\n\t\t\t\t\t\t\t\t\t\t\t\t0\r\n\t\t\t\t\t\t\t\t\t\t\t'

# %%
# a = song_rank50[0].find_all('div', attrs={'class':'wrap_song_info'})

# rank_list = []

# for i in range(0, 100):
#     if (i < 50 ):
#         rank_list.append(song_rank50[i].find('div', class_='wrap t_center').text)
#     elif i >=50 or i < 100:
#         rank_list.append(song_rank100[i-50].find('div', class_='wrap t_center').text)

# d = {}

# for rank in rank_list:
#     if i < 50:
#         d[rank].append([song_rank50[i].find('div',class_='ellipsis rank01').text])
#         d[rank].extend([song_rank50[i].find('div',class_='ellipsis rank02').text])
#     elif i >= 50 or i < 100:
#         d[rank].append([song_rank100[i-50].find('div',class_='ellipsis rank01').text])
#         d[rank].extend([song_rank100[i-50].find('div',class_='ellipsis rank02').text])


# for i in range(0,100):

#     print(song_rank50[i].find('div', class_='wrap t_center').text)
#     print("곡명:", song_rank50[i].find('div',class_='ellipsis rank01').text)
#     print("가수 명:", song_rank50[i].find('div',class_='ellipsis rank02').text)

# %%
melon_dict = {}
for i in range(0, 100):
    if i < 50:
        rank = song_rank50[i].find('div', class_='wrap t_center').text
        song_name = song_rank50[i].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank50[i].find('div',class_='ellipsis rank02').text.strip('\n')
    elif i >= 50 or i < 100:
        rank = song_rank100[i-50].find('div', class_='wrap t_center').text
        song_name = song_rank100[i-50].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank100[i-50].find('div',class_='ellipsis rank02').text.strip('\n')
        
    melon_dict[rank] = {'song name':song_name, 'singer name':singer_name}
        
melon_dict
# melon_dict = {}

# for i in range(0,100):
#     if i < 50:
#         melon_dict
# Out:
# {'1위': {'song name': 'Supernova', 'singer name': 'aespaaespa'},
#  '2위': {'song name': 'How Sweet', 'singer name': 'NewJeansNewJeans'},
#  '3위': {'song name': 'Bubble Gum', 'singer name': 'NewJeansNewJeans'},
#  '4위': {'song name': '소나기', 'singer name': '이클립스 (ECLIPSE)이클립스 (ECLIPSE)'},
#  '5위': {'song name': 'SPOT! (feat. JENNIE)',
#   'singer name': '지코 (ZICO)지코 (ZICO)'},
#  '6위': {'song name': '해야 (HEYA)', 'singer name': 'IVE (아이브)IVE (아이브)'},
#  '7위': {'song name': '고민중독', 'singer name': 'QWERQWER'},
#  '8위': {'song name': 'Armageddon', 'singer name': 'aespaaespa'},
#  '9위': {'song name': 'Magnetic', 'singer name': '아일릿(ILLIT)아일릿(ILLIT)'},
#  '10위': {'song name': '나는 아픈 건 딱 질색이니까', 'singer name': '(여자)아이들(여자)아이들'},
#  '11위': {'song name': '첫 만남은 계획대로 되지 않아', 'singer name': 'TWS (투어스)TWS (투어스)'},
#  '12위': {'song name': '미안해 미워해 사랑해', 'singer name': 'CrushCrush'},
#  '13위': {'song name': '천상연', 'singer name': '이창섭이창섭'},
#  '14위': {'song name': '한 페이지가 될 수 있게',
# ...

# %%
melon_dict = {"rank":[],"song_name":[],"singer_name":[]}
for i in range(0, 100):
    if i < 50:
        rank = song_rank50[i].find('div', class_='wrap t_center').text
        song_name = song_rank50[i].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank50[i].find('span',class_='checkEllipsis').text.strip('\n')
        
    elif i >= 50 or i < 100:
        rank = song_rank100[i-50].find('div', class_='wrap t_center').text
        song_name = song_rank100[i-50].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank100[i-50].find('span',class_='checkEllipsis').text.strip('\n')
        
    melon_dict["rank"].append(rank)
    melon_dict["song_name"].append(song_name)
    melon_dict["singer_name"].append(singer_name)
        
melon_dict
# melon_dict = {}

# for i in range(0,100):
#     if i < 50:
#         melon_dict
# Out:
# {'rank': ['1위',
#   '2위',
#   '3위',
#   '4위',
#   '5위',
#   '6위',
#   '7위',
#   '8위',
#   '9위',
#   '10위',
#   '11위',
#   '12위',
#   '13위',
#   '14위',
#   '15위',
#   '16위',
#   '17위',
#   '18위',
#   '19위',
#   '20위',
#   '21위',
#   '22위',
#   '23위',
#   '24위',
#   '25위',
#   '26위',
#   '27위',
#   '28위',
#   '29위',
#   '30위',
#   '31위',
#   '32위',
#   '33위',
#   '34위',
#   '35위',
#   '36위',
#   '37위',
#   '38위',
#   '39위',
#   '40위',
#   '41위',
#   '42위',
#   '43위',
#   '44위',
#   '45위',
#   '46위',
#   '47위',
#   '48위',
#   '49위',
#   '50위',
#   '51위',
#   '52위',
#   '53위',
#   '54위',
#   '55위',
#   '56위',
#   '57위',
#   '58위',
#   '59위',
#   '60위',
#   '61위',
#   '62위',
#   '63위',
#   '64위',
#   '65위',
#   '66위',
#   '67위',
#   '68위',
#   '69위',
#   '70위',
#   '71위',
#   '72위',
#   '73위',
#   '74위',
#   '75위',
#   '76위',
#   '77위',
#   '78위',
#   '79위',
#   '80위',
#   '81위',
#   '82위',
#   '83위',
#   '84위',
#   '85위',
#   '86위',
#   '87위',
#   '88위',
#   '89위',
#   '90위',
#   '91위',
# ...

# %%
# extend로 바꾸니 출력이 이상해짐
# extend는 딕셔너리와 리스트 혹은 리스트와 리스트등 과 같은 경우일때 써준다.
# 아래와 같은 상황에서는 string을 추가하는 경우이니 append를 써줘도 되지만
# kyobo_crawling과 같이 리스트 안에 있는 요소를 넣고 싶을 때는 extend를 써준다.
temp_dict = {"rank":[],"song_name":[],"singer_name":[]}
for i in range(0, 100):
    if i < 50:
        rank = song_rank50[i].find('div', class_='wrap t_center').text
        song_name = song_rank50[i].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank50[i].find('span',class_='checkEllipsis').text.strip('\n')
        
    elif i >= 50 or i < 100:
        rank = song_rank100[i-50].find('div', class_='wrap t_center').text
        song_name = song_rank100[i-50].find('div',class_='ellipsis rank01').text.strip('\n')
        singer_name = song_rank100[i-50].find('span',class_='checkEllipsis').text.strip('\n')
        
    temp_dict["rank"].extend(rank)
    temp_dict["song_name"].extend(song_name)
    temp_dict["singer_name"].extend(singer_name)
        
temp_dict
# Out:
# {'rank': ['1',
#   '위',
#   '2',
#   '위',
#   '3',
#   '위',
#   '4',
#   '위',
#   '5',
#   '위',
#   '6',
#   '위',
#   '7',
#   '위',
#   '8',
#   '위',
#   '9',
#   '위',
#   '1',
#   '0',
#   '위',
#   '1',
#   '1',
#   '위',
#   '1',
#   '2',
#   '위',
#   '1',
#   '3',
#   '위',
#   '1',
#   '4',
#   '위',
#   '1',
#   '5',
#   '위',
#   '1',
#   '6',
#   '위',
#   '1',
#   '7',
#   '위',
#   '1',
#   '8',
#   '위',
#   '1',
#   '9',
#   '위',
#   '2',
#   '0',
#   '위',
#   '2',
#   '1',
#   '위',
#   '2',
#   '2',
#   '위',
#   '2',
#   '3',
#   '위',
#   '2',
#   '4',
#   '위',
#   '2',
#   '5',
#   '위',
#   '2',
#   '6',
#   '위',
#   '2',
#   '7',
#   '위',
#   '2',
#   '8',
#   '위',
#   '2',
#   '9',
#   '위',
#   '3',
#   '0',
#   '위',
#   '3',
#   '1',
#   '위',
#   '3',
#   '2',
#   '위',
#   '3',
#   '3',
#   '위',
#   '3',
#   '4',
#   '위',
#   '3',
#   '5',
#   '위',
#   '3',
#   '6',
#   '위',
#   '3',
#   '7',
#   '위',
#   '3',
#   '8',
#   '위',
#   '3',
#   '9',
#   '위',
#   '4',
#   '0',
# ...

# %%
# import pandas as pd

# 에러!!
# pd.DataFrame(temp_dict)

# %%
import pandas as pd

pd.DataFrame(melon_dict)
# Out:
#     rank             song_name      singer_name
# 0     1위             Supernova            aespa
# 1     2위             How Sweet         NewJeans
# 2     3위            Bubble Gum         NewJeans
# 3     4위                   소나기   이클립스 (ECLIPSE)
# 4     5위  SPOT! (feat. JENNIE)        지코 (ZICO)
# ..   ...                   ...              ...
# 95   96위         Watch Me Woo!            PLAVE
# 96   97위                 꿈결같아서     민니 ((여자)아이들)
# 97   98위                  청춘찬가  세븐틴 (SEVENTEEN)
# 98   99위                Kitsch        IVE (아이브)
# 99  100위             Blue Moon  엔플라잉 (N.Flying)
#
# [100 rows x 3 columns]
